# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import scipy.sparse as sp
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
import igraph as ig
import torch
from torch import nn
from torch.nn import functional as F
from torch.nn import Parameter
import torch.optim as optim
import math
import time
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ### Loading Dataset

# %%
data_list = []
flist = []
def import_node_db():
  global flist,data_list
  data_list = ["Stockholm","Saarbrucken","Freiburg"]
    
  floor_list1 = ["floor4_1","floor4_2","floor4_3","floor4_4","floor4_5","floor4_6","floor4_7","floor4_8",
                   "floor5_1","floor5_2","floor5_3","floor5_4","floor5_5","floor5_6","floor5_7","floor5_8",
                   "floor6_1","floor6_2","floor6_3","floor6_4","floor6_5","floor6_6","floor6_7","floor6_8","floor6_9",
                   "floor6_10","floor6_11","floor6_12","floor6_13","floor6_14","floor6_15","floor6_16","floor6_17","floor6_18",
                   "floor7_1","floor7_2","floor7_3","floor7_4","floor7_5","floor7_6","floor7_7","floor7_8"]

  floor_list2 = ["seq1_cloudy1","seq1_cloudy2","seq1_cloudy3","seq1_night1","seq1_night2","seq1_night3",
                 "seq2_cloudy1","seq2_cloudy2","seq2_cloudy3","seq2_night1","seq2_night2","seq2_night3",
                 "seq3_cloudy1","seq3_cloudy2","seq3_cloudy3","seq3_cloudy4","seq3_cloudy5","seq3_night1","seq3_night2","seq3_night3","seq3_sunny1","seq3_sunny2","seq3_sunny3",
                 "seq4_cloudy1","seq4_cloudy2","seq4_cloudy3","seq4_night1","seq4_night2","seq4_night3","seq4_sunny1","seq4_sunny2","seq4_sunny3"]

  floor_list3 = ["seq1_cloudy1","seq1_cloudy2","seq1_cloudy3","seq1_night1","seq1_night2","seq1_night3","seq1_sunny1","seq1_sunny2","seq1_sunny3","seq1_sunny4",
                 "seq2_cloudy1","seq2_cloudy2","seq2_cloudy3","seq2_night1","seq2_night2","seq2_night3","seq2_sunny1","seq2_sunny2","seq2_sunny3","seq2_sunny4",
                 "seq3_cloudy1","seq3_cloudy2","seq3_cloudy3","seq3_sunny1","seq3_sunny2","seq3_sunny3"]    

  flist = [floor_list1,floor_list2,floor_list3]
  # return flist
  node_df_list = []
  for i in range(3):
    df_list = []
    for j in flist[i]:
      if(i==0):
        p=6
      else:
        p=4
      node_df1 = pd.read_table("F:/prooo/dataset/{}/{}/nodes.dat".format(data_list[i],j),sep="\s+")
      # node_df1['floor']=j
      # node_df1['loc']=data_list[i]
      for k in range(8):
        node_df1["new_neighbor_ID_{}".format(k)] = [str(col) +"-"+ str(j) + "-" + str(data_list[i][:3])  for col in node_df1["neighbor_ID_{}".format(k)]]
      # node_df1['locfloor']=data_list[i]+"-"+j
      node_df1['node_id']=[str(col) +"-"+ str(j) + "-" + str(data_list[i][:3]) for col in node_df1['node_id']]
      node_df1['locfloor']=data_list[i]+"-"+j[:p]
      df_list.append(node_df1)
    node_df_list.append(pd.concat(df_list,ignore_index=True))
  main_list = pd.concat(node_df_list,ignore_index=True)
  return main_list
data = import_node_db()
data.head()
# Out:
#           node_id  placeholder         x         y        d1        d2  \
# 0  0-floor4_1-Sto            0 -1.000001 -0.200001 -1.025785 -0.097851
# 1  1-floor4_1-Sto            0 -0.140001  0.259999 -0.303640 -0.002786
# 2  2-floor4_1-Sto            0 -2.020001 -0.080001 -2.015833 -0.073241
# 3  3-floor4_1-Sto            0 -2.860001  0.499999 -3.019827  0.500790
# 4  4-floor4_1-Sto            0 -2.820001 -0.500001 -2.986465 -0.450972
#
#          d3        d4 label            d5  ...  view_num_7  new_neighbor_ID_0  \
# 0 -1.000001 -0.200001    EV  1.205846e+09  ...           0     1-floor4_1-Sto
# 1 -0.200001  0.599999    EV  1.205846e+09  ...           0     0-floor4_1-Sto
# 2 -1.800001 -0.200001    DW  1.205846e+09  ...           1     0-floor4_1-Sto
# 3 -2.600001  0.599999    CR  1.205846e+09  ...           0     2-floor4_1-Sto
# 4 -2.600001 -0.200001    CR  1.205846e+09  ...           1     2-floor4_1-Sto
#
#    new_neighbor_ID_1  new_neighbor_ID_2  new_neighbor_ID_3  new_neighbor_ID_4  \
# 0     2-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 1    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 2     3-floor4_1-Sto     4-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 3     4-floor4_1-Sto     6-floor4_1-Sto     9-floor4_1-Sto    -1-floor4_1-Sto
# 4     3-floor4_1-Sto     5-floor4_1-Sto     6-floor4_1-Sto    -1-floor4_1-Sto
#
#    new_neighbor_ID_5  new_neighbor_ID_6  new_neighbor_ID_7          locfloor
# 0    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 1    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 2    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 3    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 4    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
#
# [5 rows x 43 columns]

# %%
node_number = 1
for i in data["node_id"]:
  # print(i)
  data = data.replace(i,node_number)
  node_number = node_number + 1

# %% [markdown]
# ### Fixing "neighbor_id" according node_id

# %%
for i in data_list:
  for j in flist:
    for k in j:
      data.replace(str(-1)+"-"+k+"-"+i[:3],0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   d1                 12009 non-null  float64
#  5   d2                 12009 non-null  float64
#  6   d3                 12009 non-null  float64
#  7   d4                 12009 non-null  float64
#  8   label              12009 non-null  object
#  9   d5                 12009 non-null  float64
#  10  neighbor_ID_0      12009 non-null  int64
#  11  affordance_0       12009 non-null  float64
#  12  view_num_0         12009 non-null  int64
#  13  neighbor_ID_1      12009 non-null  int64
#  14  affordance_1       12009 non-null  float64
#  15  view_num_1         12009 non-null  int64
#  16  neighbor_ID_2      12009 non-null  int64
#  17  affordance_2       12009 non-null  float64
#  18  view_num_2         12009 non-null  int64
#  19  neighbor_ID_3      12009 non-null  int64
#  20  affordance_3       12009 non-null  float64
#  21  view_num_3         12009 non-null  int64
#  22  neighbor_ID_4      12009 non-null  int64
#  23  affordance_4       12009 non-null  float64
#  24  view_num_4         12009 non-null  int64
#  25  neighbor_ID_5      12009 non-null  int64
#  26  affordance_5       12009 non-null  float64
#  27  view_num_5         12009 non-null  int64
#  28  neighbor_ID_6      12009 non-null  int64
#  29  affordance_6       12009 non-null  float64
#  30  view_num_6         12009 non-null  int64
#  31  neighbor_ID_7      12009 non-null  int64
#  32  affordance_7       12009 non-null  float64
#  33  view_num_7         12009 non-null  int64
#  34  new_neighbor_ID_0  12009 non-null  int64
#  35  new_neighbor_ID_1  12009 non-null  int64
#  36  new_neighbor_ID_2  12009 non-null  int64
#  37  new_neighbor_ID_3  12009 non-null  int64
#  38  new_neighbor_ID_4  12009 non-null  int64
#  39  new_neighbor_ID_5  12009 non-null  int64
#  40  new_neighbor_ID_6  12009 non-null  int64
#  41  new_neighbor_ID_7  12009 non-null  int64
#  42  locfloor           12009 non-null  object
# dtypes: float64(15), int64(26), object(2)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Dropping out unnecessary columns

# %%
df = data.drop(['d1','d2','d3','d4','d5','neighbor_ID_0','neighbor_ID_1','neighbor_ID_2','neighbor_ID_3','neighbor_ID_4','neighbor_ID_5','neighbor_ID_6','neighbor_ID_7'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   label              12009 non-null  object
#  5   affordance_0       12009 non-null  float64
#  6   view_num_0         12009 non-null  int64
#  7   affordance_1       12009 non-null  float64
#  8   view_num_1         12009 non-null  int64
#  9   affordance_2       12009 non-null  float64
#  10  view_num_2         12009 non-null  int64
#  11  affordance_3       12009 non-null  float64
#  12  view_num_3         12009 non-null  int64
#  13  affordance_4       12009 non-null  float64
#  14  view_num_4         12009 non-null  int64
#  15  affordance_5       12009 non-null  float64
#  16  view_num_5         12009 non-null  int64
#  17  affordance_6       12009 non-null  float64
#  18  view_num_6         12009 non-null  int64
#  19  affordance_7       12009 non-null  float64
#  20  view_num_7         12009 non-null  int64
#  21  new_neighbor_ID_0  12009 non-null  int64
#  22  new_neighbor_ID_1  12009 non-null  int64
#  23  new_neighbor_ID_2  12009 non-null  int64
#  24  new_neighbor_ID_3  12009 non-null  int64
#  25  new_neighbor_ID_4  12009 non-null  int64
#  26  new_neighbor_ID_5  12009 non-null  int64
#  27  new_neighbor_ID_6  12009 non-null  int64
#  28  new_neighbor_ID_7  12009 non-null  int64
#  29  locfloor           12009 non-null  object
# dtypes: float64(10), int64(18), object(2)
# memory usage: 2.7+ MB

# %%
y = np.array(df['label'])
df['label'].unique().shape
# Out:
# (22,)

# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from keras.utils import to_categorical

# %%
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['locfloor']= label_encoder.fit_transform(df['locfloor'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   label              12009 non-null  object
#  5   affordance_0       12009 non-null  float64
#  6   view_num_0         12009 non-null  int64
#  7   affordance_1       12009 non-null  float64
#  8   view_num_1         12009 non-null  int64
#  9   affordance_2       12009 non-null  float64
#  10  view_num_2         12009 non-null  int64
#  11  affordance_3       12009 non-null  float64
#  12  view_num_3         12009 non-null  int64
#  13  affordance_4       12009 non-null  float64
#  14  view_num_4         12009 non-null  int64
#  15  affordance_5       12009 non-null  float64
#  16  view_num_5         12009 non-null  int64
#  17  affordance_6       12009 non-null  float64
#  18  view_num_6         12009 non-null  int64
#  19  affordance_7       12009 non-null  float64
#  20  view_num_7         12009 non-null  int64
#  21  new_neighbor_ID_0  12009 non-null  int64
#  22  new_neighbor_ID_1  12009 non-null  int64
#  23  new_neighbor_ID_2  12009 non-null  int64
#  24  new_neighbor_ID_3  12009 non-null  int64
#  25  new_neighbor_ID_4  12009 non-null  int64
#  26  new_neighbor_ID_5  12009 non-null  int64
#  27  new_neighbor_ID_6  12009 non-null  int64
#  28  new_neighbor_ID_7  12009 non-null  int64
#  29  locfloor           12009 non-null  int32
# dtypes: float64(10), int32(1), int64(18), object(1)
# memory usage: 2.7+ MB

# %%
def encode_onehot(labels):
    classes = set(labels)
    classes_dict = {c: np.identity(len(classes))[i, :] for i, c in enumerate(classes)}
    labels_onehot = np.array(list(map(classes_dict.get, labels)), dtype=np.int32)
    return labels_onehot

# %%
labels = encode_onehot(np.array(df['label']))
labels.shape
# Out:
# (12009, 22)

# %%
df = df.drop(['label'],axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   affordance_0       12009 non-null  float64
#  5   view_num_0         12009 non-null  int64
#  6   affordance_1       12009 non-null  float64
#  7   view_num_1         12009 non-null  int64
#  8   affordance_2       12009 non-null  float64
#  9   view_num_2         12009 non-null  int64
#  10  affordance_3       12009 non-null  float64
#  11  view_num_3         12009 non-null  int64
#  12  affordance_4       12009 non-null  float64
#  13  view_num_4         12009 non-null  int64
#  14  affordance_5       12009 non-null  float64
#  15  view_num_5         12009 non-null  int64
#  16  affordance_6       12009 non-null  float64
#  17  view_num_6         12009 non-null  int64
#  18  affordance_7       12009 non-null  float64
#  19  view_num_7         12009 non-null  int64
#  20  new_neighbor_ID_0  12009 non-null  int64
#  21  new_neighbor_ID_1  12009 non-null  int64
#  22  new_neighbor_ID_2  12009 non-null  int64
#  23  new_neighbor_ID_3  12009 non-null  int64
#  24  new_neighbor_ID_4  12009 non-null  int64
#  25  new_neighbor_ID_5  12009 non-null  int64
#  26  new_neighbor_ID_6  12009 non-null  int64
#  27  new_neighbor_ID_7  12009 non-null  int64
#  28  locfloor           12009 non-null  int32
# dtypes: float64(10), int32(1), int64(18)
# memory usage: 2.6 MB

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X = np.array(df)
print(X.shape)
X = np.reshape(X, (12009, 29, 1))
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)
# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# Out:
# (12009, 29)

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(29,1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(22, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 121/121 [==============================] - 1s 6ms/step - loss: 3.0534 - accuracy: 0.3322 - val_loss: 4.2839 - val_accuracy: 0.2055
# Epoch 2/100
# 121/121 [==============================] - 1s 6ms/step - loss: 3.4005 - accuracy: 0.3305 - val_loss: 5.8916 - val_accuracy: 0.1545
# Epoch 3/100
# 121/121 [==============================] - 1s 6ms/step - loss: 3.3414 - accuracy: 0.3379 - val_loss: 3.2507 - val_accuracy: 0.3694
# Epoch 4/100
# 121/121 [==============================] - 1s 6ms/step - loss: 3.1806 - accuracy: 0.3477 - val_loss: 3.0421 - val_accuracy: 0.3783
# Epoch 5/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.7358 - accuracy: 0.3689 - val_loss: 2.8499 - val_accuracy: 0.3569
# Epoch 6/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.6751 - accuracy: 0.3682 - val_loss: 4.4223 - val_accuracy: 0.2440
# Epoch 7/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.5849 - accuracy: 0.3758 - val_loss: 3.1551 - val_accuracy: 0.3959
# Epoch 8/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.5956 - accuracy: 0.3880 - val_loss: 4.1879 - val_accuracy: 0.2019
# Epoch 9/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.4659 - accuracy: 0.4161 - val_loss: 4.0486 - val_accuracy: 0.2144
# Epoch 10/100
# 121/121 [==============================] - 1s 6ms/step - loss: 2.1504 - accuracy: 0.4340 - val_loss: 1.7531 - val_accuracy: 0.4558
# Epoch 11/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.9833 - accuracy: 0.4522 - val_loss: 2.1115 - val_accuracy: 0.4121
# Epoch 12/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.8479 - accuracy: 0.4700 - val_loss: 2.7230 - val_accuracy: 0.3143
# Epoch 13/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.8373 - accuracy: 0.4911 - val_loss: 3.1881 - val_accuracy: 0.3085
# Epoch 14/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.8064 - accuracy: 0.5010 - val_loss: 2.0960 - val_accuracy: 0.4573
# Epoch 15/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.7418 - accuracy: 0.5084 - val_loss: 1.8038 - val_accuracy: 0.5026
# Epoch 16/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.5995 - accuracy: 0.5247 - val_loss: 1.8809 - val_accuracy: 0.5099
# Epoch 17/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.6161 - accuracy: 0.5271 - val_loss: 1.6475 - val_accuracy: 0.4984
# Epoch 18/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.4378 - accuracy: 0.5619 - val_loss: 1.5942 - val_accuracy: 0.4719
# Epoch 19/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.4238 - accuracy: 0.5619 - val_loss: 1.4307 - val_accuracy: 0.5520
# Epoch 20/100
# 121/121 [==============================] - 1s 7ms/step - loss: 1.3852 - accuracy: 0.5696 - val_loss: 1.3281 - val_accuracy: 0.5728
# Epoch 21/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.3378 - accuracy: 0.5874 - val_loss: 1.5595 - val_accuracy: 0.5447
# Epoch 22/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.2703 - accuracy: 0.5980 - val_loss: 2.0261 - val_accuracy: 0.4084
# Epoch 23/100
# 121/121 [==============================] - 1s 7ms/step - loss: 1.3335 - accuracy: 0.5926 - val_loss: 1.2971 - val_accuracy: 0.6217
# Epoch 24/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.2086 - accuracy: 0.6118 - val_loss: 1.5482 - val_accuracy: 0.5905
# Epoch 25/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.2456 - accuracy: 0.6146 - val_loss: 1.2996 - val_accuracy: 0.5926
# Epoch 26/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.0601 - accuracy: 0.6522 - val_loss: 1.2431 - val_accuracy: 0.6379
# Epoch 27/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.0808 - accuracy: 0.6480 - val_loss: 1.3525 - val_accuracy: 0.6243
# Epoch 28/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.0931 - accuracy: 0.6501 - val_loss: 1.3427 - val_accuracy: 0.5921
# Epoch 29/100
# 121/121 [==============================] - 1s 6ms/step - loss: 1.1180 - accuracy: 0.6462 - val_loss: 1.1554 - val_accuracy: 0.6374
# Epoch 30/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.9695 - accuracy: 0.6834 - val_loss: 1.1726 - val_accuracy: 0.6550
# Epoch 31/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.9318 - accuracy: 0.6928 - val_loss: 0.9473 - val_accuracy: 0.6873
# Epoch 32/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.9311 - accuracy: 0.7012 - val_loss: 0.9772 - val_accuracy: 0.6738
# Epoch 33/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.8940 - accuracy: 0.7045 - val_loss: 0.9275 - val_accuracy: 0.6961
# Epoch 34/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.8272 - accuracy: 0.7183 - val_loss: 1.1903 - val_accuracy: 0.6290
# Epoch 35/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.8366 - accuracy: 0.7179 - val_loss: 0.8353 - val_accuracy: 0.7206
# Epoch 36/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.7671 - accuracy: 0.7361 - val_loss: 0.8097 - val_accuracy: 0.7435
# Epoch 37/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.7452 - accuracy: 0.7524 - val_loss: 0.8975 - val_accuracy: 0.7097
# Epoch 38/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.6986 - accuracy: 0.7595 - val_loss: 0.7701 - val_accuracy: 0.7404
# Epoch 39/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.7296 - accuracy: 0.7541 - val_loss: 0.8225 - val_accuracy: 0.7263
# Epoch 40/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.7126 - accuracy: 0.7554 - val_loss: 0.7648 - val_accuracy: 0.7607
# Epoch 41/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.6763 - accuracy: 0.7729 - val_loss: 0.7470 - val_accuracy: 0.7440
# Epoch 42/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.6652 - accuracy: 0.7753 - val_loss: 0.7408 - val_accuracy: 0.7529
# Epoch 43/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.6286 - accuracy: 0.7845 - val_loss: 0.7048 - val_accuracy: 0.7513
# Epoch 44/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.6107 - accuracy: 0.7893 - val_loss: 0.7754 - val_accuracy: 0.7367
# Epoch 45/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.6248 - accuracy: 0.7876 - val_loss: 0.6353 - val_accuracy: 0.7867
# Epoch 46/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.5735 - accuracy: 0.8026 - val_loss: 0.6056 - val_accuracy: 0.7960
# Epoch 47/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.5385 - accuracy: 0.8130 - val_loss: 0.6518 - val_accuracy: 0.7773
# Epoch 48/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.5570 - accuracy: 0.8091 - val_loss: 0.6555 - val_accuracy: 0.7732
# Epoch 49/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.5325 - accuracy: 0.8172 - val_loss: 0.7179 - val_accuracy: 0.7518
# Epoch 50/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.5287 - accuracy: 0.8151 - val_loss: 0.6093 - val_accuracy: 0.7950
# Epoch 51/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.5125 - accuracy: 0.8232 - val_loss: 0.5450 - val_accuracy: 0.8174
# Epoch 52/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4808 - accuracy: 0.8319 - val_loss: 0.6370 - val_accuracy: 0.7945
# Epoch 53/100
# 121/121 [==============================] - 1s 5ms/step - loss: 0.4745 - accuracy: 0.8375 - val_loss: 0.5699 - val_accuracy: 0.8210
# Epoch 54/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4803 - accuracy: 0.8364 - val_loss: 0.5317 - val_accuracy: 0.8174
# Epoch 55/100
# 121/121 [==============================] - 1s 5ms/step - loss: 0.5110 - accuracy: 0.8278 - val_loss: 0.5368 - val_accuracy: 0.8210
# Epoch 56/100
# 121/121 [==============================] - 1s 5ms/step - loss: 0.4309 - accuracy: 0.8553 - val_loss: 0.6496 - val_accuracy: 0.7794
# Epoch 57/100
# 121/121 [==============================] - 1s 5ms/step - loss: 0.4434 - accuracy: 0.8445 - val_loss: 0.5939 - val_accuracy: 0.7903
# Epoch 58/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4241 - accuracy: 0.8502 - val_loss: 0.5179 - val_accuracy: 0.8267
# Epoch 59/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4280 - accuracy: 0.8530 - val_loss: 0.5100 - val_accuracy: 0.8252
# Epoch 60/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4029 - accuracy: 0.8636 - val_loss: 0.4728 - val_accuracy: 0.8460
# Epoch 61/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3931 - accuracy: 0.8656 - val_loss: 0.4961 - val_accuracy: 0.8283
# Epoch 62/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3744 - accuracy: 0.8729 - val_loss: 0.4741 - val_accuracy: 0.8465
# Epoch 63/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.4009 - accuracy: 0.8648 - val_loss: 0.5067 - val_accuracy: 0.8304
# Epoch 64/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.4083 - accuracy: 0.8595 - val_loss: 0.4630 - val_accuracy: 0.8450
# Epoch 65/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3660 - accuracy: 0.8717 - val_loss: 0.4619 - val_accuracy: 0.8392
# Epoch 66/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3687 - accuracy: 0.8688 - val_loss: 0.4779 - val_accuracy: 0.8512
# Epoch 67/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3467 - accuracy: 0.8795 - val_loss: 0.3906 - val_accuracy: 0.8704
# Epoch 68/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3397 - accuracy: 0.8835 - val_loss: 0.4429 - val_accuracy: 0.8517
# Epoch 69/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3464 - accuracy: 0.8869 - val_loss: 0.4654 - val_accuracy: 0.8351
# Epoch 70/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3381 - accuracy: 0.8851 - val_loss: 0.4676 - val_accuracy: 0.8429
# Epoch 71/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3399 - accuracy: 0.8868 - val_loss: 0.4194 - val_accuracy: 0.8658
# Epoch 72/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3180 - accuracy: 0.8912 - val_loss: 0.4482 - val_accuracy: 0.8413
# Epoch 73/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3168 - accuracy: 0.8934 - val_loss: 0.4716 - val_accuracy: 0.8392
# Epoch 74/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3146 - accuracy: 0.8939 - val_loss: 0.3927 - val_accuracy: 0.8741
# Epoch 75/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.3195 - accuracy: 0.8912 - val_loss: 0.4229 - val_accuracy: 0.8554
# Epoch 76/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2991 - accuracy: 0.8997 - val_loss: 0.6309 - val_accuracy: 0.7919
# Epoch 77/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3158 - accuracy: 0.8971 - val_loss: 0.3644 - val_accuracy: 0.8866
# Epoch 78/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2707 - accuracy: 0.9113 - val_loss: 0.4416 - val_accuracy: 0.8585
# Epoch 79/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3044 - accuracy: 0.8964 - val_loss: 0.3982 - val_accuracy: 0.8658
# Epoch 80/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2756 - accuracy: 0.9077 - val_loss: 0.4306 - val_accuracy: 0.8616
# Epoch 81/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2496 - accuracy: 0.9169 - val_loss: 0.3614 - val_accuracy: 0.8814
# Epoch 82/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2666 - accuracy: 0.9094 - val_loss: 0.4848 - val_accuracy: 0.8371
# Epoch 83/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2537 - accuracy: 0.9128 - val_loss: 0.4067 - val_accuracy: 0.8668
# Epoch 84/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2221 - accuracy: 0.9287 - val_loss: 0.3884 - val_accuracy: 0.8694
# Epoch 85/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.9142 - val_loss: 0.3585 - val_accuracy: 0.8876
# Epoch 86/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2277 - accuracy: 0.9227 - val_loss: 0.3444 - val_accuracy: 0.8928
# Epoch 87/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2273 - accuracy: 0.9243 - val_loss: 0.3796 - val_accuracy: 0.8736
# Epoch 88/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.2529 - accuracy: 0.9137 - val_loss: 0.3228 - val_accuracy: 0.8949
# Epoch 89/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2122 - accuracy: 0.9309 - val_loss: 0.3198 - val_accuracy: 0.8996
# Epoch 90/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2180 - accuracy: 0.9273 - val_loss: 0.3770 - val_accuracy: 0.8689
# Epoch 91/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2185 - accuracy: 0.9254 - val_loss: 0.4132 - val_accuracy: 0.8470
# Epoch 92/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.2237 - accuracy: 0.9243 - val_loss: 0.3404 - val_accuracy: 0.8975
# Epoch 93/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.2089 - accuracy: 0.9318 - val_loss: 0.3127 - val_accuracy: 0.9011
# Epoch 94/100
# 121/121 [==============================] - 1s 7ms/step - loss: 0.2020 - accuracy: 0.9343 - val_loss: 0.5130 - val_accuracy: 0.8377
# Epoch 95/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.3095 - accuracy: 0.9005 - val_loss: 0.3133 - val_accuracy: 0.8996
# Epoch 96/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.1779 - accuracy: 0.9421 - val_loss: 0.3451 - val_accuracy: 0.8788
# Epoch 97/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.1963 - accuracy: 0.9335 - val_loss: 0.2988 - val_accuracy: 0.9001
# Epoch 98/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.1799 - accuracy: 0.9413 - val_loss: 0.2962 - val_accuracy: 0.9136
# Epoch 99/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.1657 - accuracy: 0.9476 - val_loss: 0.2732 - val_accuracy: 0.9204
# Epoch 100/100
# 121/121 [==============================] - 1s 6ms/step - loss: 0.1688 - accuracy: 0.9464 - val_loss: 0.3460 - val_accuracy: 0.8835

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8975853323936462
