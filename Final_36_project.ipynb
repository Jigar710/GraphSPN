# %% [markdown]
# # *Learning Semantic Maps with Topological Spatial Relations*

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import scipy.sparse as sp
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
import igraph as ig
import torch
from torch import nn
from torch.nn import functional as F
from torch.nn import Parameter
import torch.optim as optim
import math
import time
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ### Loading Dataset

# %%
data_list = []
flist = []
def import_node_db():
  global flist,data_list
  data_list = ["Stockholm","Saarbrucken","Freiburg"]
    
  floor_list1 = ["floor4_1","floor4_2","floor4_3","floor4_4","floor4_5","floor4_6","floor4_7","floor4_8",
                   "floor5_1","floor5_2","floor5_3","floor5_4","floor5_5","floor5_6","floor5_7","floor5_8",
                   "floor6_1","floor6_2","floor6_3","floor6_4","floor6_5","floor6_6","floor6_7","floor6_8","floor6_9",
                   "floor6_10","floor6_11","floor6_12","floor6_13","floor6_14","floor6_15","floor6_16","floor6_17","floor6_18",
                   "floor7_1","floor7_2","floor7_3","floor7_4","floor7_5","floor7_6","floor7_7","floor7_8"]

  floor_list2 = ["seq1_cloudy1","seq1_cloudy2","seq1_cloudy3","seq1_night1","seq1_night2","seq1_night3",
                 "seq2_cloudy1","seq2_cloudy2","seq2_cloudy3","seq2_night1","seq2_night2","seq2_night3",
                 "seq3_cloudy1","seq3_cloudy2","seq3_cloudy3","seq3_cloudy4","seq3_cloudy5","seq3_night1","seq3_night2","seq3_night3","seq3_sunny1","seq3_sunny2","seq3_sunny3",
                 "seq4_cloudy1","seq4_cloudy2","seq4_cloudy3","seq4_night1","seq4_night2","seq4_night3","seq4_sunny1","seq4_sunny2","seq4_sunny3"]

  floor_list3 = ["seq1_cloudy1","seq1_cloudy2","seq1_cloudy3","seq1_night1","seq1_night2","seq1_night3","seq1_sunny1","seq1_sunny2","seq1_sunny3","seq1_sunny4",
                 "seq2_cloudy1","seq2_cloudy2","seq2_cloudy3","seq2_night1","seq2_night2","seq2_night3","seq2_sunny1","seq2_sunny2","seq2_sunny3","seq2_sunny4",
                 "seq3_cloudy1","seq3_cloudy2","seq3_cloudy3","seq3_sunny1","seq3_sunny2","seq3_sunny3"]    

  flist = [floor_list1,floor_list2,floor_list3]
  # return flist
  node_df_list = []
  for i in range(3):
    df_list = []
    for j in flist[i]:
      if(i==0):
        p=6
      else:
        p=4
      node_df1 = pd.read_table("F:/prooo/dataset/{}/{}/nodes.dat".format(data_list[i],j),sep="\s+")
      # node_df1['floor']=j
      # node_df1['loc']=data_list[i]
      for k in range(8):
        node_df1["new_neighbor_ID_{}".format(k)] = [str(col) +"-"+ str(j) + "-" + str(data_list[i][:3])  for col in node_df1["neighbor_ID_{}".format(k)]]
      # node_df1['locfloor']=data_list[i]+"-"+j
      node_df1['node_id']=[str(col) +"-"+ str(j) + "-" + str(data_list[i][:3]) for col in node_df1['node_id']]
      node_df1['locfloor']=data_list[i]+"-"+j[:p]
      df_list.append(node_df1)
    node_df_list.append(pd.concat(df_list,ignore_index=True))
  main_list = pd.concat(node_df_list,ignore_index=True)
  return main_list
data = import_node_db()
data.head()
# Out:
#           node_id  placeholder         x         y        d1        d2  \
# 0  0-floor4_1-Sto            0 -1.000001 -0.200001 -1.025785 -0.097851
# 1  1-floor4_1-Sto            0 -0.140001  0.259999 -0.303640 -0.002786
# 2  2-floor4_1-Sto            0 -2.020001 -0.080001 -2.015833 -0.073241
# 3  3-floor4_1-Sto            0 -2.860001  0.499999 -3.019827  0.500790
# 4  4-floor4_1-Sto            0 -2.820001 -0.500001 -2.986465 -0.450972
#
#          d3        d4 label            d5  ...  view_num_7  new_neighbor_ID_0  \
# 0 -1.000001 -0.200001    EV  1.205846e+09  ...           0     1-floor4_1-Sto
# 1 -0.200001  0.599999    EV  1.205846e+09  ...           0     0-floor4_1-Sto
# 2 -1.800001 -0.200001    DW  1.205846e+09  ...           1     0-floor4_1-Sto
# 3 -2.600001  0.599999    CR  1.205846e+09  ...           0     2-floor4_1-Sto
# 4 -2.600001 -0.200001    CR  1.205846e+09  ...           1     2-floor4_1-Sto
#
#    new_neighbor_ID_1  new_neighbor_ID_2  new_neighbor_ID_3  new_neighbor_ID_4  \
# 0     2-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 1    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 2     3-floor4_1-Sto     4-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto
# 3     4-floor4_1-Sto     6-floor4_1-Sto     9-floor4_1-Sto    -1-floor4_1-Sto
# 4     3-floor4_1-Sto     5-floor4_1-Sto     6-floor4_1-Sto    -1-floor4_1-Sto
#
#    new_neighbor_ID_5  new_neighbor_ID_6  new_neighbor_ID_7          locfloor
# 0    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 1    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 2    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 3    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
# 4    -1-floor4_1-Sto    -1-floor4_1-Sto    -1-floor4_1-Sto  Stockholm-floor4
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Getting data for graph

# %%
graph_data = []
graph_data.append(pd.read_table("F:/prooo/dataset/Stockholm/floor4_1/nodes.dat",sep="\s+"))
graph_data.append(pd.read_table("F:/prooo/dataset/Saarbrucken/seq1_cloudy1/nodes.dat",sep="\s+"))
graph_data.append(pd.read_table("F:/prooo/dataset/Freiburg/seq1_cloudy1/nodes.dat",sep="\s+"))
graph_data[0].shape
# Out:
# (122, 34)

# %% [markdown]
# ### Getting edges for graph

# %%
def get_graph_edge(gdata):
    temp_lst = []
    for i,data in gdata.iterrows():
          edges = []
          if(data.neighbor_ID_0!=-1):
                if (data.neighbor_ID_0,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_0))
          if(data.neighbor_ID_1!=-1):
                if (data.neighbor_ID_0,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_1))
          if(data.neighbor_ID_2!=-1):
                if (data.neighbor_ID_2,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_2))
          if(data.neighbor_ID_3!=-1):
                if (data.neighbor_ID_3,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_3))
          if(data.neighbor_ID_4!=-1):
                if (data.neighbor_ID_4,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_4))
          if(data.neighbor_ID_5!=-1):
                if (data.neighbor_ID_5,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_5))
          if(data.neighbor_ID_6!=-1):
                if (data.neighbor_ID_6,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_6))
          if(data.neighbor_ID_7!=-1):
                if (data.neighbor_ID_7,data.node_id) not in temp_lst:
                    edges.append((data.node_id,data.neighbor_ID_7))
          temp_lst.extend(edges)
    return temp_lst

# %%
edges_data = []
for graph in graph_data:
    temp_lst = []
    edges_data.append(get_graph_edge(graph))

# %%
n_vertices = []
for i in graph_data:
    n_vertices.append(i.shape[0])
n_vertices
# Out:
# [122, 75, 88]

# %%
g1 = ig.Graph(n_vertices[0], edges_data[0])
g2 = ig.Graph(n_vertices[1], edges_data[1])
g3 = ig.Graph(n_vertices[2], edges_data[1])

# %%
g1.vs["name"] = graph_data[0].label
g2.vs["name"] = graph_data[1].label
g3.vs["name"] = graph_data[2].label

# %%
from igraph import RainbowPalette
fig, axis = plt.subplots(figsize=(15,15))
ig.plot(
    g1,
    target=axis,
    vertex_size=1.5,
    vertex_frame_width=0.8,
    vertex_color = RainbowPalette(n=n_vertices[0], s=1, v=0.8, alpha=1.00),
    vertex_frame_color="white",
    vertex_label=g1.vs["name"],
    vertex_label_size=6.0,
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Settling down "node_id"

# %%
node_number = 1
for i in data["node_id"]:
  # print(i)
  data = data.replace(i,node_number)
  node_number = node_number + 1

# %% [markdown]
# ### Fixing "neighbor_id" according node_id

# %%
for i in data_list:
  for j in flist:
    for k in j:
      data.replace(str(-1)+"-"+k+"-"+i[:3],0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   d1                 12009 non-null  float64
#  5   d2                 12009 non-null  float64
#  6   d3                 12009 non-null  float64
#  7   d4                 12009 non-null  float64
#  8   label              12009 non-null  object
#  9   d5                 12009 non-null  float64
#  10  neighbor_ID_0      12009 non-null  int64
#  11  affordance_0       12009 non-null  float64
#  12  view_num_0         12009 non-null  int64
#  13  neighbor_ID_1      12009 non-null  int64
#  14  affordance_1       12009 non-null  float64
#  15  view_num_1         12009 non-null  int64
#  16  neighbor_ID_2      12009 non-null  int64
#  17  affordance_2       12009 non-null  float64
#  18  view_num_2         12009 non-null  int64
#  19  neighbor_ID_3      12009 non-null  int64
#  20  affordance_3       12009 non-null  float64
#  21  view_num_3         12009 non-null  int64
#  22  neighbor_ID_4      12009 non-null  int64
#  23  affordance_4       12009 non-null  float64
#  24  view_num_4         12009 non-null  int64
#  25  neighbor_ID_5      12009 non-null  int64
#  26  affordance_5       12009 non-null  float64
#  27  view_num_5         12009 non-null  int64
#  28  neighbor_ID_6      12009 non-null  int64
#  29  affordance_6       12009 non-null  float64
#  30  view_num_6         12009 non-null  int64
#  31  neighbor_ID_7      12009 non-null  int64
#  32  affordance_7       12009 non-null  float64
#  33  view_num_7         12009 non-null  int64
#  34  new_neighbor_ID_0  12009 non-null  int64
#  35  new_neighbor_ID_1  12009 non-null  int64
#  36  new_neighbor_ID_2  12009 non-null  int64
#  37  new_neighbor_ID_3  12009 non-null  int64
#  38  new_neighbor_ID_4  12009 non-null  int64
#  39  new_neighbor_ID_5  12009 non-null  int64
#  40  new_neighbor_ID_6  12009 non-null  int64
#  41  new_neighbor_ID_7  12009 non-null  int64
#  42  locfloor           12009 non-null  object
# dtypes: float64(15), int64(26), object(2)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Dropping out unnecessary columns

# %%
df = data.drop(['d1','d2','d3','d4','d5','neighbor_ID_0','neighbor_ID_1','neighbor_ID_2','neighbor_ID_3','neighbor_ID_4','neighbor_ID_5','neighbor_ID_6','neighbor_ID_7'], axis=1)

# %% [markdown]
# ### Encoding of object(string) column

# %%
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['locfloor']= label_encoder.fit_transform(df['locfloor'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12009 entries, 0 to 12008
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   node_id            12009 non-null  int64
#  1   placeholder        12009 non-null  int64
#  2   x                  12009 non-null  float64
#  3   y                  12009 non-null  float64
#  4   label              12009 non-null  object
#  5   affordance_0       12009 non-null  float64
#  6   view_num_0         12009 non-null  int64
#  7   affordance_1       12009 non-null  float64
#  8   view_num_1         12009 non-null  int64
#  9   affordance_2       12009 non-null  float64
#  10  view_num_2         12009 non-null  int64
#  11  affordance_3       12009 non-null  float64
#  12  view_num_3         12009 non-null  int64
#  13  affordance_4       12009 non-null  float64
#  14  view_num_4         12009 non-null  int64
#  15  affordance_5       12009 non-null  float64
#  16  view_num_5         12009 non-null  int64
#  17  affordance_6       12009 non-null  float64
#  18  view_num_6         12009 non-null  int64
#  19  affordance_7       12009 non-null  float64
#  20  view_num_7         12009 non-null  int64
#  21  new_neighbor_ID_0  12009 non-null  int64
#  22  new_neighbor_ID_1  12009 non-null  int64
#  23  new_neighbor_ID_2  12009 non-null  int64
#  24  new_neighbor_ID_3  12009 non-null  int64
#  25  new_neighbor_ID_4  12009 non-null  int64
#  26  new_neighbor_ID_5  12009 non-null  int64
#  27  new_neighbor_ID_6  12009 non-null  int64
#  28  new_neighbor_ID_7  12009 non-null  int64
#  29  locfloor           12009 non-null  int32
# dtypes: float64(10), int32(1), int64(18), object(1)
# memory usage: 2.7+ MB

# %% [markdown]
# ### one hot encoding of target

# %%
def encode_onehot(labels):
    classes = set(labels)
    classes_dict = {c: np.identity(len(classes))[i, :] for i, c in enumerate(classes)}
    labels_onehot = np.array(list(map(classes_dict.get, labels)), dtype=np.int32)
    return labels_onehot

# %%
labels = encode_onehot(np.array(df['label']))
labels.shape
# Out:
# (12009, 22)

# %% [markdown]
# ### Getting edges

# %%
def get_edge(data):
  edges = []
  if(data.new_neighbor_ID_0!=0):
    edges.append([data.node_id,data.new_neighbor_ID_0,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_1!=0):
    edges.append([data.node_id,data.new_neighbor_ID_1,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_2!=0):
    edges.append([data.node_id,data.new_neighbor_ID_2,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_3!=0):
    edges.append([data.node_id,data.new_neighbor_ID_3,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_4!=0):
    edges.append([data.node_id,data.new_neighbor_ID_4,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_5!=0):
    edges.append([data.node_id,data.new_neighbor_ID_5,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_6!=0):
    edges.append([data.node_id,data.new_neighbor_ID_6,data.locfloor])
  else:
    pass
  if(data.new_neighbor_ID_7!=0):
    edges.append([data.node_id,data.new_neighbor_ID_7,data.locfloor])
  else:
    pass
  return edges

# %%
graph_edges = []
for i,raw_data in df.iterrows():
  graph_edges.extend(get_edge(raw_data))
edges_unordered = np.array(graph_edges)
edges_unordered.shape
# Out:
# (42769, 3)

# %% [markdown]
# ### Getting Degree Function

# %%
def get_degree(data):
    lst1 = []
    lst2 = []
    in_degree = []
    out_degree = []
    for i in range(data.shape[0]):
        lst1.append(data[i][1])
        lst2.append(data[i][0])
    for i in range(1,1000):
        in_degree.append(lst1.count(i))
        out_degree.append(lst2.count(i))
    return in_degree,out_degree

# %%
Y_indeg, Y_outdeg = get_degree(edges_unordered)

# %% [markdown]
# ### Plotting

# %%
fig = plt.figure(figsize=(12,8), dpi=200)  # otherwise plots are really small in Jupyter Notebook
fig.subplots_adjust(hspace=0.6)
plt.subplot(311)
plt.plot(Y_indeg, color='red')
plt.xlabel('node id'); plt.ylabel('in-degree count'); plt.title('Input degree for different node ids')

plt.subplot(312)
plt.plot(Y_outdeg, color='green')
plt.xlabel('node id'); plt.ylabel('out-degree count'); plt.title('Out degree for different node ids')

hist = np.zeros(np.max(Y_outdeg) + 1)
for out_degree in Y_outdeg:
    hist[out_degree] += 1
    
plt.subplot(313)
plt.plot(hist, color='blue')
plt.xlabel('node degree')
plt.ylabel('# nodes for a given out-degree') 
plt.title(f'Node out-degree distribution for dataset')
plt.xticks(np.arange(0, len(hist), 5.0))
# Out:
# ([<matplotlib.axis.XTick at 0x1abaa875358>,
#   <matplotlib.axis.XTick at 0x1abaa868cc0>],
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
idx = np.array(df.index, dtype=np.int32)
idx_map = {j: i for i, j in enumerate(idx)}
idx.shape
# Out:
# (12009,)

# %%
df = df.drop(['node_id','label'], axis=1)

# %%
from sklearn.preprocessing import normalize
edges_unordered = normalize(edges_unordered)

# %%
features = sp.csr_matrix(df, dtype=np.float32)
edges = np.array(edges_unordered)
print(edges.shape)
adj = sp.coo_matrix(
        (np.ones(edges.shape[0]), 
        (edges[:, 0], edges[:, 1])),
        shape=(labels.shape[0], labels.shape[0]),
        dtype=np.float32
)
# Out:
# (42769, 3)

# %% [markdown]
# ### Normalization of Features & adj matrix

# %%
def normalize(mx):
    """
    Row-normalize sparse matrix
    """
    rowsum = np.array(mx.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    mx = r_mat_inv.dot(mx)
    return mx

# %%
features = normalize(features)
adj = normalize(adj + sp.eye(adj.shape[0]))

# %%
idx_train = range(9000)
idx_val = range(9000, 11000)
idx_test = range(11000, 12000)

# %%
def sparse_mx_to_torch_sparse_tensor(sparse_mx):
    """
    Convert a scipy sparse matrix to a torch sparse tensor.
    """
    sparse_mx = sparse_mx.tocoo().astype(np.float32)
    indices = torch.from_numpy(
        np.vstack((sparse_mx.row, sparse_mx.col)).astype(np.int64))
    values = torch.from_numpy(sparse_mx.data)
    shape = torch.Size(sparse_mx.shape)
    return torch.sparse.FloatTensor(indices, values, shape)

# %% [markdown]
# ### Making Tensors

# %%
features = torch.FloatTensor(np.array(features.todense()))
labels = torch.LongTensor(np.where(labels)[1])
adj = sparse_mx_to_torch_sparse_tensor(adj)

# %%
idx_train = torch.LongTensor(idx_train)
idx_val = torch.LongTensor(idx_val)
idx_test = torch.LongTensor(idx_test)

# %% [markdown]
# ### Checking for cuda availability

# %%
torch.cuda.is_available()
# Out:
# True

# %%
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# ### GNN model

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.nn import Parameter
import math


class GraphConvolution(nn.Module):
    def __init__(self, in_features, out_features, bias=True):
        super(GraphConvolution, self).__init__()

        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.FloatTensor(in_features, out_features))

        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))        
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj):
        support = torch.mm(input, self.weight)
        output = torch.spmm(adj, support)
        if self.bias is not None:
            return output + self.bias
        else:
            return output

    def __repr__(self):
        return f'{self.__class__.__name__} ({self.in_features} -> {self.out_features})'


class GCN(nn.Module):
    def __init__(self, nfeat, nhid, nclass, dropout):
        super(GCN, self).__init__()

        self.gc1 = GraphConvolution(nfeat, nhid)
        self.gc2 = GraphConvolution(nhid, nclass)
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.gc2(x, adj)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ### Model Instance

# %%
model = GCN(
        nfeat=features.shape[1],
        nhid=16,
        nclass=labels.max().item() + 1,
        dropout=0.5
    )

# %%
optimizer = optim.SGD(
        model.parameters(),
        lr=0.01, 
        weight_decay=5e-4
    )

# %%
model.cuda()
features = features.cuda()
adj = adj.cuda()
labels = labels.cuda()
idx_train = idx_train.cuda()
idx_val = idx_val.cuda()
idx_test = idx_test.cuda()

# %% [markdown]
# ### Train, Accuracy & Test Functions

# %%
def train(model,adj, epoch):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    print(features.shape)
    output = model(features, adj)
    loss_train = F.nll_loss(output[idx_train], labels[idx_train])
    acc_train = accuracy(output[idx_train], labels[idx_train])
    loss_train.backward()
    optimizer.step()

    # if not args.fastmode:
    #     # Evaluate validation set performance separately,
    #     # deactivates dropout during validation run.
    model.eval()
    output = model(features, adj)

    loss_val = F.nll_loss(output[idx_val], labels[idx_val])
    acc_val = accuracy(output[idx_val], labels[idx_val])
    print('Epoch: {:04d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train.item()),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'acc_val: {:.4f}'.format(acc_val.item()),
          'time: {:.4f}s'.format(time.time() - t))

# %%
def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()
    return correct / len(labels)

# %%
def test(model):
    model.eval()
    output = model(features, adj)
    loss_test = F.nll_loss(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    print("Test set results:", "loss= {:.4f}".format(loss_test.item()), "accuracy= {:.4f}".format(acc_test.item()))

# %% [markdown]
# ### Training

# %%
t_total = time.time()
for epoch in range(500):
  train(model, adj, epoch)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
# Out:
# torch.Size([12009, 28])
# Epoch: 0001 loss_train: 2.6430 acc_train: 0.2710 loss_val: 2.4666 acc_val: 0.3955 time: 0.3073s
# torch.Size([12009, 28])
# Epoch: 0002 loss_train: 2.6379 acc_train: 0.2710 loss_val: 2.4666 acc_val: 0.3955 time: 0.0212s
# torch.Size([12009, 28])
# Epoch: 0003 loss_train: 2.6392 acc_train: 0.2710 loss_val: 2.4665 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0004 loss_train: 2.6365 acc_train: 0.2710 loss_val: 2.4664 acc_val: 0.3955 time: 0.0313s
# torch.Size([12009, 28])
# Epoch: 0005 loss_train: 2.6360 acc_train: 0.2710 loss_val: 2.4663 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0006 loss_train: 2.6390 acc_train: 0.2710 loss_val: 2.4663 acc_val: 0.3955 time: 0.0246s
# torch.Size([12009, 28])
# Epoch: 0007 loss_train: 2.6389 acc_train: 0.2710 loss_val: 2.4662 acc_val: 0.3955 time: 0.0119s
# torch.Size([12009, 28])
# Epoch: 0008 loss_train: 2.6384 acc_train: 0.2710 loss_val: 2.4661 acc_val: 0.3955 time: 0.0116s
# torch.Size([12009, 28])
# Epoch: 0009 loss_train: 2.6378 acc_train: 0.2710 loss_val: 2.4660 acc_val: 0.3955 time: 0.0125s
# torch.Size([12009, 28])
# Epoch: 0010 loss_train: 2.6388 acc_train: 0.2710 loss_val: 2.4660 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0011 loss_train: 2.6370 acc_train: 0.2710 loss_val: 2.4659 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0012 loss_train: 2.6383 acc_train: 0.2710 loss_val: 2.4659 acc_val: 0.3955 time: 0.0239s
# torch.Size([12009, 28])
# Epoch: 0013 loss_train: 2.6367 acc_train: 0.2710 loss_val: 2.4658 acc_val: 0.3955 time: 0.0034s
# torch.Size([12009, 28])
# Epoch: 0014 loss_train: 2.6374 acc_train: 0.2710 loss_val: 2.4657 acc_val: 0.3955 time: 0.0207s
# torch.Size([12009, 28])
# Epoch: 0015 loss_train: 2.6431 acc_train: 0.2710 loss_val: 2.4657 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0016 loss_train: 2.6393 acc_train: 0.2710 loss_val: 2.4656 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0017 loss_train: 2.6356 acc_train: 0.2710 loss_val: 2.4656 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0018 loss_train: 2.6341 acc_train: 0.2710 loss_val: 2.4655 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0019 loss_train: 2.6345 acc_train: 0.2710 loss_val: 2.4654 acc_val: 0.3955 time: 0.0157s
# torch.Size([12009, 28])
# Epoch: 0020 loss_train: 2.6365 acc_train: 0.2710 loss_val: 2.4654 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0021 loss_train: 2.6358 acc_train: 0.2710 loss_val: 2.4653 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0022 loss_train: 2.6388 acc_train: 0.2710 loss_val: 2.4652 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0023 loss_train: 2.6358 acc_train: 0.2710 loss_val: 2.4652 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0024 loss_train: 2.6355 acc_train: 0.2710 loss_val: 2.4651 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0025 loss_train: 2.6384 acc_train: 0.2710 loss_val: 2.4650 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0026 loss_train: 2.6348 acc_train: 0.2710 loss_val: 2.4650 acc_val: 0.3955 time: 0.0244s
# torch.Size([12009, 28])
# Epoch: 0027 loss_train: 2.6378 acc_train: 0.2710 loss_val: 2.4649 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0028 loss_train: 2.6387 acc_train: 0.2710 loss_val: 2.4649 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0029 loss_train: 2.6391 acc_train: 0.2710 loss_val: 2.4648 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0030 loss_train: 2.6381 acc_train: 0.2710 loss_val: 2.4648 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0031 loss_train: 2.6347 acc_train: 0.2710 loss_val: 2.4647 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0032 loss_train: 2.6339 acc_train: 0.2710 loss_val: 2.4646 acc_val: 0.3955 time: 0.0134s
# torch.Size([12009, 28])
# Epoch: 0033 loss_train: 2.6313 acc_train: 0.2710 loss_val: 2.4646 acc_val: 0.3955 time: 0.0110s
# torch.Size([12009, 28])
# Epoch: 0034 loss_train: 2.6365 acc_train: 0.2710 loss_val: 2.4645 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0035 loss_train: 2.6299 acc_train: 0.2710 loss_val: 2.4644 acc_val: 0.3955 time: 0.0143s
# torch.Size([12009, 28])
# Epoch: 0036 loss_train: 2.6364 acc_train: 0.2710 loss_val: 2.4644 acc_val: 0.3955 time: 0.0100s
# torch.Size([12009, 28])
# Epoch: 0037 loss_train: 2.6363 acc_train: 0.2710 loss_val: 2.4643 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0038 loss_train: 2.6314 acc_train: 0.2710 loss_val: 2.4642 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0039 loss_train: 2.6361 acc_train: 0.2710 loss_val: 2.4642 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0040 loss_train: 2.6364 acc_train: 0.2710 loss_val: 2.4641 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0041 loss_train: 2.6301 acc_train: 0.2710 loss_val: 2.4641 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0042 loss_train: 2.6350 acc_train: 0.2710 loss_val: 2.4640 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0043 loss_train: 2.6337 acc_train: 0.2710 loss_val: 2.4640 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0044 loss_train: 2.6335 acc_train: 0.2710 loss_val: 2.4639 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0045 loss_train: 2.6333 acc_train: 0.2710 loss_val: 2.4638 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0046 loss_train: 2.6330 acc_train: 0.2710 loss_val: 2.4638 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0047 loss_train: 2.6321 acc_train: 0.2710 loss_val: 2.4637 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0048 loss_train: 2.6358 acc_train: 0.2710 loss_val: 2.4637 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0049 loss_train: 2.6363 acc_train: 0.2710 loss_val: 2.4636 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0050 loss_train: 2.6285 acc_train: 0.2710 loss_val: 2.4635 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0051 loss_train: 2.6373 acc_train: 0.2710 loss_val: 2.4635 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0052 loss_train: 2.6304 acc_train: 0.2710 loss_val: 2.4634 acc_val: 0.3955 time: 0.0239s
# torch.Size([12009, 28])
# Epoch: 0053 loss_train: 2.6350 acc_train: 0.2710 loss_val: 2.4634 acc_val: 0.3955 time: 0.0083s
# torch.Size([12009, 28])
# Epoch: 0054 loss_train: 2.6292 acc_train: 0.2710 loss_val: 2.4633 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0055 loss_train: 2.6265 acc_train: 0.2710 loss_val: 2.4632 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0056 loss_train: 2.6328 acc_train: 0.2710 loss_val: 2.4632 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0057 loss_train: 2.6330 acc_train: 0.2710 loss_val: 2.4631 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0058 loss_train: 2.6347 acc_train: 0.2710 loss_val: 2.4631 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0059 loss_train: 2.6374 acc_train: 0.2710 loss_val: 2.4630 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0060 loss_train: 2.6349 acc_train: 0.2710 loss_val: 2.4630 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0061 loss_train: 2.6352 acc_train: 0.2710 loss_val: 2.4630 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0062 loss_train: 2.6304 acc_train: 0.2710 loss_val: 2.4629 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0063 loss_train: 2.6296 acc_train: 0.2710 loss_val: 2.4628 acc_val: 0.3955 time: 0.0238s
# torch.Size([12009, 28])
# Epoch: 0064 loss_train: 2.6289 acc_train: 0.2710 loss_val: 2.4628 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0065 loss_train: 2.6342 acc_train: 0.2710 loss_val: 2.4627 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0066 loss_train: 2.6356 acc_train: 0.2710 loss_val: 2.4627 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0067 loss_train: 2.6314 acc_train: 0.2710 loss_val: 2.4626 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0068 loss_train: 2.6327 acc_train: 0.2710 loss_val: 2.4625 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0069 loss_train: 2.6321 acc_train: 0.2710 loss_val: 2.4625 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0070 loss_train: 2.6297 acc_train: 0.2710 loss_val: 2.4624 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0071 loss_train: 2.6328 acc_train: 0.2710 loss_val: 2.4624 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0072 loss_train: 2.6316 acc_train: 0.2710 loss_val: 2.4623 acc_val: 0.3955 time: 0.0263s
# torch.Size([12009, 28])
# Epoch: 0073 loss_train: 2.6346 acc_train: 0.2710 loss_val: 2.4623 acc_val: 0.3955 time: 0.0131s
# torch.Size([12009, 28])
# Epoch: 0074 loss_train: 2.6315 acc_train: 0.2710 loss_val: 2.4623 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0075 loss_train: 2.6278 acc_train: 0.2710 loss_val: 2.4622 acc_val: 0.3955 time: 0.0136s
# torch.Size([12009, 28])
# Epoch: 0076 loss_train: 2.6332 acc_train: 0.2710 loss_val: 2.4621 acc_val: 0.3955 time: 0.0100s
# torch.Size([12009, 28])
# Epoch: 0077 loss_train: 2.6348 acc_train: 0.2710 loss_val: 2.4621 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0078 loss_train: 2.6274 acc_train: 0.2710 loss_val: 2.4620 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0079 loss_train: 2.6343 acc_train: 0.2710 loss_val: 2.4620 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0080 loss_train: 2.6342 acc_train: 0.2710 loss_val: 2.4619 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0081 loss_train: 2.6316 acc_train: 0.2710 loss_val: 2.4619 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0082 loss_train: 2.6285 acc_train: 0.2710 loss_val: 2.4618 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0083 loss_train: 2.6310 acc_train: 0.2710 loss_val: 2.4618 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0084 loss_train: 2.6300 acc_train: 0.2710 loss_val: 2.4618 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0085 loss_train: 2.6288 acc_train: 0.2710 loss_val: 2.4617 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0086 loss_train: 2.6330 acc_train: 0.2710 loss_val: 2.4617 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0087 loss_train: 2.6321 acc_train: 0.2710 loss_val: 2.4616 acc_val: 0.3955 time: 0.0082s
# torch.Size([12009, 28])
# Epoch: 0088 loss_train: 2.6281 acc_train: 0.2710 loss_val: 2.4616 acc_val: 0.3955 time: 0.0183s
# torch.Size([12009, 28])
# Epoch: 0089 loss_train: 2.6303 acc_train: 0.2710 loss_val: 2.4615 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0090 loss_train: 2.6297 acc_train: 0.2710 loss_val: 2.4615 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0091 loss_train: 2.6313 acc_train: 0.2710 loss_val: 2.4614 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0092 loss_train: 2.6303 acc_train: 0.2710 loss_val: 2.4614 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0093 loss_train: 2.6337 acc_train: 0.2710 loss_val: 2.4613 acc_val: 0.3955 time: 0.0184s
# torch.Size([12009, 28])
# Epoch: 0094 loss_train: 2.6308 acc_train: 0.2710 loss_val: 2.4613 acc_val: 0.3955 time: 0.0135s
# torch.Size([12009, 28])
# Epoch: 0095 loss_train: 2.6273 acc_train: 0.2710 loss_val: 2.4612 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0096 loss_train: 2.6275 acc_train: 0.2710 loss_val: 2.4612 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0097 loss_train: 2.6298 acc_train: 0.2710 loss_val: 2.4611 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0098 loss_train: 2.6334 acc_train: 0.2710 loss_val: 2.4611 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0099 loss_train: 2.6276 acc_train: 0.2710 loss_val: 2.4610 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0100 loss_train: 2.6261 acc_train: 0.2710 loss_val: 2.4610 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0101 loss_train: 2.6288 acc_train: 0.2710 loss_val: 2.4609 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0102 loss_train: 2.6315 acc_train: 0.2710 loss_val: 2.4609 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0103 loss_train: 2.6289 acc_train: 0.2710 loss_val: 2.4608 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0104 loss_train: 2.6284 acc_train: 0.2710 loss_val: 2.4608 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0105 loss_train: 2.6318 acc_train: 0.2710 loss_val: 2.4608 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0106 loss_train: 2.6286 acc_train: 0.2710 loss_val: 2.4607 acc_val: 0.3955 time: 0.0056s
# torch.Size([12009, 28])
# Epoch: 0107 loss_train: 2.6302 acc_train: 0.2710 loss_val: 2.4607 acc_val: 0.3955 time: 0.0177s
# torch.Size([12009, 28])
# Epoch: 0108 loss_train: 2.6248 acc_train: 0.2710 loss_val: 2.4606 acc_val: 0.3955 time: 0.0125s
# torch.Size([12009, 28])
# Epoch: 0109 loss_train: 2.6248 acc_train: 0.2710 loss_val: 2.4606 acc_val: 0.3955 time: 0.0062s
# torch.Size([12009, 28])
# Epoch: 0110 loss_train: 2.6247 acc_train: 0.2710 loss_val: 2.4605 acc_val: 0.3955 time: 0.0141s
# torch.Size([12009, 28])
# Epoch: 0111 loss_train: 2.6266 acc_train: 0.2710 loss_val: 2.4605 acc_val: 0.3955 time: 0.0129s
# torch.Size([12009, 28])
# Epoch: 0112 loss_train: 2.6286 acc_train: 0.2710 loss_val: 2.4605 acc_val: 0.3955 time: 0.0028s
# torch.Size([12009, 28])
# Epoch: 0113 loss_train: 2.6227 acc_train: 0.2710 loss_val: 2.4604 acc_val: 0.3955 time: 0.0211s
# torch.Size([12009, 28])
# Epoch: 0114 loss_train: 2.6274 acc_train: 0.2710 loss_val: 2.4603 acc_val: 0.3955 time: 0.0158s
# torch.Size([12009, 28])
# Epoch: 0115 loss_train: 2.6292 acc_train: 0.2710 loss_val: 2.4603 acc_val: 0.3955 time: 0.0135s
# torch.Size([12009, 28])
# Epoch: 0116 loss_train: 2.6250 acc_train: 0.2710 loss_val: 2.4602 acc_val: 0.3955 time: 0.0172s
# torch.Size([12009, 28])
# Epoch: 0117 loss_train: 2.6261 acc_train: 0.2710 loss_val: 2.4602 acc_val: 0.3955 time: 0.0128s
# torch.Size([12009, 28])
# Epoch: 0118 loss_train: 2.6283 acc_train: 0.2710 loss_val: 2.4602 acc_val: 0.3955 time: 0.0134s
# torch.Size([12009, 28])
# Epoch: 0119 loss_train: 2.6213 acc_train: 0.2710 loss_val: 2.4601 acc_val: 0.3955 time: 0.0072s
# torch.Size([12009, 28])
# Epoch: 0120 loss_train: 2.6283 acc_train: 0.2710 loss_val: 2.4600 acc_val: 0.3955 time: 0.0170s
# torch.Size([12009, 28])
# Epoch: 0121 loss_train: 2.6284 acc_train: 0.2710 loss_val: 2.4600 acc_val: 0.3955 time: 0.0123s
# torch.Size([12009, 28])
# Epoch: 0122 loss_train: 2.6290 acc_train: 0.2710 loss_val: 2.4600 acc_val: 0.3955 time: 0.0089s
# torch.Size([12009, 28])
# Epoch: 0123 loss_train: 2.6281 acc_train: 0.2710 loss_val: 2.4599 acc_val: 0.3955 time: 0.0113s
# torch.Size([12009, 28])
# Epoch: 0124 loss_train: 2.6240 acc_train: 0.2710 loss_val: 2.4599 acc_val: 0.3955 time: 0.0133s
# torch.Size([12009, 28])
# Epoch: 0125 loss_train: 2.6269 acc_train: 0.2710 loss_val: 2.4598 acc_val: 0.3955 time: 0.0071s
# torch.Size([12009, 28])
# Epoch: 0126 loss_train: 2.6280 acc_train: 0.2710 loss_val: 2.4598 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0127 loss_train: 2.6258 acc_train: 0.2710 loss_val: 2.4597 acc_val: 0.3955 time: 0.0101s
# torch.Size([12009, 28])
# Epoch: 0128 loss_train: 2.6255 acc_train: 0.2710 loss_val: 2.4597 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0129 loss_train: 2.6302 acc_train: 0.2710 loss_val: 2.4597 acc_val: 0.3955 time: 0.0140s
# torch.Size([12009, 28])
# Epoch: 0130 loss_train: 2.6250 acc_train: 0.2710 loss_val: 2.4596 acc_val: 0.3955 time: 0.0184s
# torch.Size([12009, 28])
# Epoch: 0131 loss_train: 2.6241 acc_train: 0.2710 loss_val: 2.4596 acc_val: 0.3955 time: 0.0135s
# torch.Size([12009, 28])
# Epoch: 0132 loss_train: 2.6257 acc_train: 0.2710 loss_val: 2.4595 acc_val: 0.3955 time: 0.0087s
# torch.Size([12009, 28])
# Epoch: 0133 loss_train: 2.6247 acc_train: 0.2710 loss_val: 2.4595 acc_val: 0.3955 time: 0.0198s
# torch.Size([12009, 28])
# Epoch: 0134 loss_train: 2.6234 acc_train: 0.2710 loss_val: 2.4594 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0135 loss_train: 2.6296 acc_train: 0.2710 loss_val: 2.4594 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0136 loss_train: 2.6277 acc_train: 0.2710 loss_val: 2.4594 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0137 loss_train: 2.6212 acc_train: 0.2710 loss_val: 2.4593 acc_val: 0.3955 time: 0.0100s
# torch.Size([12009, 28])
# Epoch: 0138 loss_train: 2.6282 acc_train: 0.2710 loss_val: 2.4593 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0139 loss_train: 2.6242 acc_train: 0.2710 loss_val: 2.4593 acc_val: 0.3955 time: 0.0153s
# torch.Size([12009, 28])
# Epoch: 0140 loss_train: 2.6243 acc_train: 0.2710 loss_val: 2.4592 acc_val: 0.3955 time: 0.0065s
# torch.Size([12009, 28])
# Epoch: 0141 loss_train: 2.6245 acc_train: 0.2710 loss_val: 2.4592 acc_val: 0.3955 time: 0.0183s
# torch.Size([12009, 28])
# Epoch: 0142 loss_train: 2.6260 acc_train: 0.2710 loss_val: 2.4591 acc_val: 0.3955 time: 0.0151s
# torch.Size([12009, 28])
# Epoch: 0143 loss_train: 2.6248 acc_train: 0.2710 loss_val: 2.4591 acc_val: 0.3955 time: 0.0115s
# torch.Size([12009, 28])
# Epoch: 0144 loss_train: 2.6257 acc_train: 0.2710 loss_val: 2.4590 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0145 loss_train: 2.6224 acc_train: 0.2710 loss_val: 2.4590 acc_val: 0.3955 time: 0.0051s
# torch.Size([12009, 28])
# Epoch: 0146 loss_train: 2.6253 acc_train: 0.2710 loss_val: 2.4590 acc_val: 0.3955 time: 0.0171s
# torch.Size([12009, 28])
# Epoch: 0147 loss_train: 2.6258 acc_train: 0.2710 loss_val: 2.4589 acc_val: 0.3955 time: 0.0162s
# torch.Size([12009, 28])
# Epoch: 0148 loss_train: 2.6224 acc_train: 0.2710 loss_val: 2.4589 acc_val: 0.3955 time: 0.0117s
# torch.Size([12009, 28])
# Epoch: 0149 loss_train: 2.6257 acc_train: 0.2710 loss_val: 2.4588 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0150 loss_train: 2.6235 acc_train: 0.2710 loss_val: 2.4588 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0151 loss_train: 2.6228 acc_train: 0.2710 loss_val: 2.4587 acc_val: 0.3955 time: 0.0052s
# torch.Size([12009, 28])
# Epoch: 0152 loss_train: 2.6221 acc_train: 0.2710 loss_val: 2.4587 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0153 loss_train: 2.6266 acc_train: 0.2710 loss_val: 2.4587 acc_val: 0.3955 time: 0.0186s
# torch.Size([12009, 28])
# Epoch: 0154 loss_train: 2.6257 acc_train: 0.2710 loss_val: 2.4587 acc_val: 0.3955 time: 0.0154s
# torch.Size([12009, 28])
# Epoch: 0155 loss_train: 2.6237 acc_train: 0.2710 loss_val: 2.4586 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0156 loss_train: 2.6274 acc_train: 0.2710 loss_val: 2.4586 acc_val: 0.3955 time: 0.0043s
# torch.Size([12009, 28])
# Epoch: 0157 loss_train: 2.6289 acc_train: 0.2710 loss_val: 2.4586 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0158 loss_train: 2.6262 acc_train: 0.2710 loss_val: 2.4585 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0159 loss_train: 2.6225 acc_train: 0.2710 loss_val: 2.4585 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0160 loss_train: 2.6277 acc_train: 0.2710 loss_val: 2.4585 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0161 loss_train: 2.6281 acc_train: 0.2710 loss_val: 2.4584 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0162 loss_train: 2.6212 acc_train: 0.2710 loss_val: 2.4584 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0163 loss_train: 2.6215 acc_train: 0.2710 loss_val: 2.4584 acc_val: 0.3955 time: 0.0095s
# torch.Size([12009, 28])
# Epoch: 0164 loss_train: 2.6243 acc_train: 0.2710 loss_val: 2.4583 acc_val: 0.3955 time: 0.0211s
# torch.Size([12009, 28])
# Epoch: 0165 loss_train: 2.6216 acc_train: 0.2710 loss_val: 2.4583 acc_val: 0.3955 time: 0.0096s
# torch.Size([12009, 28])
# Epoch: 0166 loss_train: 2.6209 acc_train: 0.2710 loss_val: 2.4583 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0167 loss_train: 2.6244 acc_train: 0.2710 loss_val: 2.4582 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0168 loss_train: 2.6215 acc_train: 0.2710 loss_val: 2.4582 acc_val: 0.3955 time: 0.0089s
# torch.Size([12009, 28])
# Epoch: 0169 loss_train: 2.6186 acc_train: 0.2710 loss_val: 2.4581 acc_val: 0.3955 time: 0.0138s
# torch.Size([12009, 28])
# Epoch: 0170 loss_train: 2.6215 acc_train: 0.2710 loss_val: 2.4581 acc_val: 0.3955 time: 0.0151s
# torch.Size([12009, 28])
# Epoch: 0171 loss_train: 2.6236 acc_train: 0.2710 loss_val: 2.4581 acc_val: 0.3955 time: 0.0132s
# torch.Size([12009, 28])
# Epoch: 0172 loss_train: 2.6243 acc_train: 0.2710 loss_val: 2.4580 acc_val: 0.3955 time: 0.0119s
# torch.Size([12009, 28])
# Epoch: 0173 loss_train: 2.6222 acc_train: 0.2710 loss_val: 2.4580 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0174 loss_train: 2.6194 acc_train: 0.2710 loss_val: 2.4580 acc_val: 0.3955 time: 0.0051s
# torch.Size([12009, 28])
# Epoch: 0175 loss_train: 2.6233 acc_train: 0.2710 loss_val: 2.4579 acc_val: 0.3955 time: 0.0196s
# torch.Size([12009, 28])
# Epoch: 0176 loss_train: 2.6164 acc_train: 0.2710 loss_val: 2.4579 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0177 loss_train: 2.6242 acc_train: 0.2710 loss_val: 2.4578 acc_val: 0.3955 time: 0.0138s
# torch.Size([12009, 28])
# Epoch: 0178 loss_train: 2.6252 acc_train: 0.2710 loss_val: 2.4578 acc_val: 0.3955 time: 0.0121s
# torch.Size([12009, 28])
# Epoch: 0179 loss_train: 2.6208 acc_train: 0.2710 loss_val: 2.4578 acc_val: 0.3955 time: 0.0132s
# torch.Size([12009, 28])
# Epoch: 0180 loss_train: 2.6241 acc_train: 0.2710 loss_val: 2.4578 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0181 loss_train: 2.6219 acc_train: 0.2710 loss_val: 2.4577 acc_val: 0.3955 time: 0.0161s
# torch.Size([12009, 28])
# Epoch: 0182 loss_train: 2.6195 acc_train: 0.2710 loss_val: 2.4577 acc_val: 0.3955 time: 0.0082s
# torch.Size([12009, 28])
# Epoch: 0183 loss_train: 2.6198 acc_train: 0.2710 loss_val: 2.4577 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0184 loss_train: 2.6225 acc_train: 0.2710 loss_val: 2.4576 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0185 loss_train: 2.6219 acc_train: 0.2710 loss_val: 2.4576 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0186 loss_train: 2.6239 acc_train: 0.2710 loss_val: 2.4576 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0187 loss_train: 2.6203 acc_train: 0.2710 loss_val: 2.4575 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0188 loss_train: 2.6216 acc_train: 0.2710 loss_val: 2.4575 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0189 loss_train: 2.6209 acc_train: 0.2710 loss_val: 2.4575 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0190 loss_train: 2.6218 acc_train: 0.2710 loss_val: 2.4575 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0191 loss_train: 2.6186 acc_train: 0.2710 loss_val: 2.4574 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0192 loss_train: 2.6214 acc_train: 0.2710 loss_val: 2.4574 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0193 loss_train: 2.6225 acc_train: 0.2710 loss_val: 2.4573 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0194 loss_train: 2.6210 acc_train: 0.2710 loss_val: 2.4573 acc_val: 0.3955 time: 0.0233s
# torch.Size([12009, 28])
# Epoch: 0195 loss_train: 2.6170 acc_train: 0.2710 loss_val: 2.4573 acc_val: 0.3955 time: 0.0092s
# torch.Size([12009, 28])
# Epoch: 0196 loss_train: 2.6276 acc_train: 0.2710 loss_val: 2.4573 acc_val: 0.3955 time: 0.0075s
# torch.Size([12009, 28])
# Epoch: 0197 loss_train: 2.6185 acc_train: 0.2710 loss_val: 2.4572 acc_val: 0.3955 time: 0.0172s
# torch.Size([12009, 28])
# Epoch: 0198 loss_train: 2.6188 acc_train: 0.2710 loss_val: 2.4572 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0199 loss_train: 2.6220 acc_train: 0.2710 loss_val: 2.4572 acc_val: 0.3955 time: 0.0198s
# torch.Size([12009, 28])
# Epoch: 0200 loss_train: 2.6231 acc_train: 0.2710 loss_val: 2.4571 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0201 loss_train: 2.6204 acc_train: 0.2710 loss_val: 2.4571 acc_val: 0.3955 time: 0.0136s
# torch.Size([12009, 28])
# Epoch: 0202 loss_train: 2.6175 acc_train: 0.2710 loss_val: 2.4571 acc_val: 0.3955 time: 0.0141s
# torch.Size([12009, 28])
# Epoch: 0203 loss_train: 2.6179 acc_train: 0.2710 loss_val: 2.4570 acc_val: 0.3955 time: 0.0057s
# torch.Size([12009, 28])
# Epoch: 0204 loss_train: 2.6190 acc_train: 0.2710 loss_val: 2.4570 acc_val: 0.3955 time: 0.0192s
# torch.Size([12009, 28])
# Epoch: 0205 loss_train: 2.6193 acc_train: 0.2710 loss_val: 2.4570 acc_val: 0.3955 time: 0.0143s
# torch.Size([12009, 28])
# Epoch: 0206 loss_train: 2.6210 acc_train: 0.2710 loss_val: 2.4570 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0207 loss_train: 2.6158 acc_train: 0.2710 loss_val: 2.4569 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0208 loss_train: 2.6256 acc_train: 0.2710 loss_val: 2.4569 acc_val: 0.3955 time: 0.0133s
# torch.Size([12009, 28])
# Epoch: 0209 loss_train: 2.6199 acc_train: 0.2710 loss_val: 2.4569 acc_val: 0.3955 time: 0.0133s
# torch.Size([12009, 28])
# Epoch: 0210 loss_train: 2.6230 acc_train: 0.2710 loss_val: 2.4569 acc_val: 0.3955 time: 0.0061s
# torch.Size([12009, 28])
# Epoch: 0211 loss_train: 2.6160 acc_train: 0.2710 loss_val: 2.4568 acc_val: 0.3955 time: 0.0178s
# torch.Size([12009, 28])
# Epoch: 0212 loss_train: 2.6189 acc_train: 0.2710 loss_val: 2.4568 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0213 loss_train: 2.6205 acc_train: 0.2710 loss_val: 2.4567 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0214 loss_train: 2.6188 acc_train: 0.2710 loss_val: 2.4567 acc_val: 0.3955 time: 0.0214s
# torch.Size([12009, 28])
# Epoch: 0215 loss_train: 2.6223 acc_train: 0.2710 loss_val: 2.4567 acc_val: 0.3955 time: 0.0046s
# torch.Size([12009, 28])
# Epoch: 0216 loss_train: 2.6197 acc_train: 0.2710 loss_val: 2.4567 acc_val: 0.3955 time: 0.0170s
# torch.Size([12009, 28])
# Epoch: 0217 loss_train: 2.6201 acc_train: 0.2710 loss_val: 2.4567 acc_val: 0.3955 time: 0.0117s
# torch.Size([12009, 28])
# Epoch: 0218 loss_train: 2.6209 acc_train: 0.2710 loss_val: 2.4566 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0219 loss_train: 2.6226 acc_train: 0.2710 loss_val: 2.4566 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0220 loss_train: 2.6164 acc_train: 0.2710 loss_val: 2.4566 acc_val: 0.3955 time: 0.0099s
# torch.Size([12009, 28])
# Epoch: 0221 loss_train: 2.6181 acc_train: 0.2710 loss_val: 2.4566 acc_val: 0.3955 time: 0.0142s
# torch.Size([12009, 28])
# Epoch: 0222 loss_train: 2.6179 acc_train: 0.2710 loss_val: 2.4565 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0223 loss_train: 2.6188 acc_train: 0.2710 loss_val: 2.4565 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0224 loss_train: 2.6140 acc_train: 0.2710 loss_val: 2.4565 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0225 loss_train: 2.6199 acc_train: 0.2710 loss_val: 2.4564 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0226 loss_train: 2.6171 acc_train: 0.2710 loss_val: 2.4564 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0227 loss_train: 2.6196 acc_train: 0.2710 loss_val: 2.4564 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0228 loss_train: 2.6171 acc_train: 0.2710 loss_val: 2.4564 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0229 loss_train: 2.6175 acc_train: 0.2710 loss_val: 2.4563 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0230 loss_train: 2.6162 acc_train: 0.2710 loss_val: 2.4563 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0231 loss_train: 2.6222 acc_train: 0.2710 loss_val: 2.4563 acc_val: 0.3955 time: 0.0186s
# torch.Size([12009, 28])
# Epoch: 0232 loss_train: 2.6180 acc_train: 0.2710 loss_val: 2.4562 acc_val: 0.3955 time: 0.0147s
# torch.Size([12009, 28])
# Epoch: 0233 loss_train: 2.6191 acc_train: 0.2710 loss_val: 2.4562 acc_val: 0.3955 time: 0.0086s
# torch.Size([12009, 28])
# Epoch: 0234 loss_train: 2.6139 acc_train: 0.2710 loss_val: 2.4562 acc_val: 0.3955 time: 0.0110s
# torch.Size([12009, 28])
# Epoch: 0235 loss_train: 2.6172 acc_train: 0.2710 loss_val: 2.4561 acc_val: 0.3955 time: 0.0179s
# torch.Size([12009, 28])
# Epoch: 0236 loss_train: 2.6198 acc_train: 0.2710 loss_val: 2.4561 acc_val: 0.3955 time: 0.0125s
# torch.Size([12009, 28])
# Epoch: 0237 loss_train: 2.6182 acc_train: 0.2710 loss_val: 2.4561 acc_val: 0.3955 time: 0.0145s
# torch.Size([12009, 28])
# Epoch: 0238 loss_train: 2.6187 acc_train: 0.2710 loss_val: 2.4561 acc_val: 0.3955 time: 0.0060s
# torch.Size([12009, 28])
# Epoch: 0239 loss_train: 2.6163 acc_train: 0.2710 loss_val: 2.4561 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0240 loss_train: 2.6172 acc_train: 0.2710 loss_val: 2.4560 acc_val: 0.3955 time: 0.0094s
# torch.Size([12009, 28])
# Epoch: 0241 loss_train: 2.6139 acc_train: 0.2710 loss_val: 2.4560 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0242 loss_train: 2.6154 acc_train: 0.2710 loss_val: 2.4560 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0243 loss_train: 2.6181 acc_train: 0.2710 loss_val: 2.4560 acc_val: 0.3955 time: 0.0162s
# torch.Size([12009, 28])
# Epoch: 0244 loss_train: 2.6156 acc_train: 0.2710 loss_val: 2.4559 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0245 loss_train: 2.6167 acc_train: 0.2710 loss_val: 2.4559 acc_val: 0.3955 time: 0.0110s
# torch.Size([12009, 28])
# Epoch: 0246 loss_train: 2.6176 acc_train: 0.2710 loss_val: 2.4559 acc_val: 0.3955 time: 0.0060s
# torch.Size([12009, 28])
# Epoch: 0247 loss_train: 2.6184 acc_train: 0.2710 loss_val: 2.4558 acc_val: 0.3955 time: 0.0210s
# torch.Size([12009, 28])
# Epoch: 0248 loss_train: 2.6175 acc_train: 0.2710 loss_val: 2.4558 acc_val: 0.3955 time: 0.0124s
# torch.Size([12009, 28])
# Epoch: 0249 loss_train: 2.6078 acc_train: 0.2710 loss_val: 2.4558 acc_val: 0.3955 time: 0.0128s
# torch.Size([12009, 28])
# Epoch: 0250 loss_train: 2.6184 acc_train: 0.2710 loss_val: 2.4558 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0251 loss_train: 2.6185 acc_train: 0.2710 loss_val: 2.4557 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0252 loss_train: 2.6139 acc_train: 0.2710 loss_val: 2.4557 acc_val: 0.3955 time: 0.0099s
# torch.Size([12009, 28])
# Epoch: 0253 loss_train: 2.6180 acc_train: 0.2710 loss_val: 2.4557 acc_val: 0.3955 time: 0.0140s
# torch.Size([12009, 28])
# Epoch: 0254 loss_train: 2.6162 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0255 loss_train: 2.6183 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0256 loss_train: 2.6186 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0257 loss_train: 2.6205 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0258 loss_train: 2.6187 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0259 loss_train: 2.6166 acc_train: 0.2710 loss_val: 2.4556 acc_val: 0.3955 time: 0.0244s
# torch.Size([12009, 28])
# Epoch: 0260 loss_train: 2.6195 acc_train: 0.2710 loss_val: 2.4555 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0261 loss_train: 2.6096 acc_train: 0.2710 loss_val: 2.4555 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0262 loss_train: 2.6191 acc_train: 0.2710 loss_val: 2.4555 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0263 loss_train: 2.6152 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0264 loss_train: 2.6170 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0265 loss_train: 2.6160 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0259s
# torch.Size([12009, 28])
# Epoch: 0266 loss_train: 2.6194 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0267 loss_train: 2.6169 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0125s
# torch.Size([12009, 28])
# Epoch: 0268 loss_train: 2.6145 acc_train: 0.2710 loss_val: 2.4554 acc_val: 0.3955 time: 0.0118s
# torch.Size([12009, 28])
# Epoch: 0269 loss_train: 2.6087 acc_train: 0.2710 loss_val: 2.4553 acc_val: 0.3955 time: 0.0089s
# torch.Size([12009, 28])
# Epoch: 0270 loss_train: 2.6182 acc_train: 0.2710 loss_val: 2.4553 acc_val: 0.3955 time: 0.0121s
# torch.Size([12009, 28])
# Epoch: 0271 loss_train: 2.6150 acc_train: 0.2710 loss_val: 2.4553 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0272 loss_train: 2.6148 acc_train: 0.2710 loss_val: 2.4553 acc_val: 0.3955 time: 0.0164s
# torch.Size([12009, 28])
# Epoch: 0273 loss_train: 2.6186 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0141s
# torch.Size([12009, 28])
# Epoch: 0274 loss_train: 2.6184 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0140s
# torch.Size([12009, 28])
# Epoch: 0275 loss_train: 2.6177 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0058s
# torch.Size([12009, 28])
# Epoch: 0276 loss_train: 2.6147 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0164s
# torch.Size([12009, 28])
# Epoch: 0277 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0100s
# torch.Size([12009, 28])
# Epoch: 0278 loss_train: 2.6196 acc_train: 0.2710 loss_val: 2.4552 acc_val: 0.3955 time: 0.0086s
# torch.Size([12009, 28])
# Epoch: 0279 loss_train: 2.6112 acc_train: 0.2710 loss_val: 2.4551 acc_val: 0.3955 time: 0.0151s
# torch.Size([12009, 28])
# Epoch: 0280 loss_train: 2.6112 acc_train: 0.2710 loss_val: 2.4551 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0281 loss_train: 2.6135 acc_train: 0.2710 loss_val: 2.4551 acc_val: 0.3955 time: 0.0168s
# torch.Size([12009, 28])
# Epoch: 0282 loss_train: 2.6162 acc_train: 0.2710 loss_val: 2.4551 acc_val: 0.3955 time: 0.0134s
# torch.Size([12009, 28])
# Epoch: 0283 loss_train: 2.6120 acc_train: 0.2710 loss_val: 2.4550 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0284 loss_train: 2.6140 acc_train: 0.2710 loss_val: 2.4550 acc_val: 0.3955 time: 0.0037s
# torch.Size([12009, 28])
# Epoch: 0285 loss_train: 2.6144 acc_train: 0.2710 loss_val: 2.4549 acc_val: 0.3955 time: 0.0157s
# torch.Size([12009, 28])
# Epoch: 0286 loss_train: 2.6142 acc_train: 0.2710 loss_val: 2.4549 acc_val: 0.3955 time: 0.0123s
# torch.Size([12009, 28])
# Epoch: 0287 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4549 acc_val: 0.3955 time: 0.0090s
# torch.Size([12009, 28])
# Epoch: 0288 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4549 acc_val: 0.3955 time: 0.0173s
# torch.Size([12009, 28])
# Epoch: 0289 loss_train: 2.6164 acc_train: 0.2710 loss_val: 2.4548 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0290 loss_train: 2.6138 acc_train: 0.2710 loss_val: 2.4548 acc_val: 0.3955 time: 0.0173s
# torch.Size([12009, 28])
# Epoch: 0291 loss_train: 2.6172 acc_train: 0.2710 loss_val: 2.4548 acc_val: 0.3955 time: 0.0145s
# torch.Size([12009, 28])
# Epoch: 0292 loss_train: 2.6138 acc_train: 0.2710 loss_val: 2.4548 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0293 loss_train: 2.6124 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0294 loss_train: 2.6152 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0295 loss_train: 2.6161 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0158s
# torch.Size([12009, 28])
# Epoch: 0296 loss_train: 2.6117 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0297 loss_train: 2.6180 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0298 loss_train: 2.6140 acc_train: 0.2710 loss_val: 2.4547 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0299 loss_train: 2.6134 acc_train: 0.2710 loss_val: 2.4546 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0300 loss_train: 2.6085 acc_train: 0.2710 loss_val: 2.4546 acc_val: 0.3955 time: 0.0120s
# torch.Size([12009, 28])
# Epoch: 0301 loss_train: 2.6137 acc_train: 0.2710 loss_val: 2.4546 acc_val: 0.3955 time: 0.0103s
# torch.Size([12009, 28])
# Epoch: 0302 loss_train: 2.6133 acc_train: 0.2710 loss_val: 2.4546 acc_val: 0.3955 time: 0.0162s
# torch.Size([12009, 28])
# Epoch: 0303 loss_train: 2.6072 acc_train: 0.2710 loss_val: 2.4545 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0304 loss_train: 2.6145 acc_train: 0.2710 loss_val: 2.4545 acc_val: 0.3955 time: 0.0138s
# torch.Size([12009, 28])
# Epoch: 0305 loss_train: 2.6134 acc_train: 0.2710 loss_val: 2.4545 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0306 loss_train: 2.6106 acc_train: 0.2710 loss_val: 2.4545 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0307 loss_train: 2.6138 acc_train: 0.2710 loss_val: 2.4544 acc_val: 0.3955 time: 0.0149s
# torch.Size([12009, 28])
# Epoch: 0308 loss_train: 2.6129 acc_train: 0.2710 loss_val: 2.4544 acc_val: 0.3955 time: 0.0045s
# torch.Size([12009, 28])
# Epoch: 0309 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4544 acc_val: 0.3955 time: 0.0180s
# torch.Size([12009, 28])
# Epoch: 0310 loss_train: 2.6158 acc_train: 0.2710 loss_val: 2.4544 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0311 loss_train: 2.6122 acc_train: 0.2710 loss_val: 2.4544 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0312 loss_train: 2.6119 acc_train: 0.2710 loss_val: 2.4543 acc_val: 0.3955 time: 0.0094s
# torch.Size([12009, 28])
# Epoch: 0313 loss_train: 2.6147 acc_train: 0.2710 loss_val: 2.4543 acc_val: 0.3955 time: 0.0209s
# torch.Size([12009, 28])
# Epoch: 0314 loss_train: 2.6130 acc_train: 0.2710 loss_val: 2.4543 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0315 loss_train: 2.6110 acc_train: 0.2710 loss_val: 2.4543 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0316 loss_train: 2.6125 acc_train: 0.2710 loss_val: 2.4543 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0317 loss_train: 2.6106 acc_train: 0.2710 loss_val: 2.4542 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0318 loss_train: 2.6095 acc_train: 0.2710 loss_val: 2.4542 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0319 loss_train: 2.6116 acc_train: 0.2710 loss_val: 2.4542 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0320 loss_train: 2.6107 acc_train: 0.2710 loss_val: 2.4542 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0321 loss_train: 2.6104 acc_train: 0.2710 loss_val: 2.4542 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0322 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4541 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0323 loss_train: 2.6119 acc_train: 0.2710 loss_val: 2.4541 acc_val: 0.3955 time: 0.0086s
# torch.Size([12009, 28])
# Epoch: 0324 loss_train: 2.6129 acc_train: 0.2710 loss_val: 2.4541 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0325 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4541 acc_val: 0.3955 time: 0.0265s
# torch.Size([12009, 28])
# Epoch: 0326 loss_train: 2.6103 acc_train: 0.2710 loss_val: 2.4541 acc_val: 0.3955 time: 0.0050s
# torch.Size([12009, 28])
# Epoch: 0327 loss_train: 2.6127 acc_train: 0.2710 loss_val: 2.4540 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0328 loss_train: 2.6115 acc_train: 0.2710 loss_val: 2.4540 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0329 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4540 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0330 loss_train: 2.6082 acc_train: 0.2710 loss_val: 2.4540 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0331 loss_train: 2.6106 acc_train: 0.2710 loss_val: 2.4539 acc_val: 0.3955 time: 0.0162s
# torch.Size([12009, 28])
# Epoch: 0332 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4539 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0333 loss_train: 2.6095 acc_train: 0.2710 loss_val: 2.4539 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0334 loss_train: 2.6127 acc_train: 0.2710 loss_val: 2.4538 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0335 loss_train: 2.6108 acc_train: 0.2710 loss_val: 2.4538 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0336 loss_train: 2.6113 acc_train: 0.2710 loss_val: 2.4538 acc_val: 0.3955 time: 0.0086s
# torch.Size([12009, 28])
# Epoch: 0337 loss_train: 2.6111 acc_train: 0.2710 loss_val: 2.4538 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0338 loss_train: 2.6107 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0126s
# torch.Size([12009, 28])
# Epoch: 0339 loss_train: 2.6131 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0036s
# torch.Size([12009, 28])
# Epoch: 0340 loss_train: 2.6108 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0204s
# torch.Size([12009, 28])
# Epoch: 0341 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0129s
# torch.Size([12009, 28])
# Epoch: 0342 loss_train: 2.6105 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0130s
# torch.Size([12009, 28])
# Epoch: 0343 loss_train: 2.6120 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0079s
# torch.Size([12009, 28])
# Epoch: 0344 loss_train: 2.6129 acc_train: 0.2710 loss_val: 2.4537 acc_val: 0.3955 time: 0.0122s
# torch.Size([12009, 28])
# Epoch: 0345 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0168s
# torch.Size([12009, 28])
# Epoch: 0346 loss_train: 2.6158 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0347 loss_train: 2.6139 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0135s
# torch.Size([12009, 28])
# Epoch: 0348 loss_train: 2.6133 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0349 loss_train: 2.6096 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0088s
# torch.Size([12009, 28])
# Epoch: 0350 loss_train: 2.6087 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0078s
# torch.Size([12009, 28])
# Epoch: 0351 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0352 loss_train: 2.6081 acc_train: 0.2710 loss_val: 2.4536 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0353 loss_train: 2.6087 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0014s
# torch.Size([12009, 28])
# Epoch: 0354 loss_train: 2.6087 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0145s
# torch.Size([12009, 28])
# Epoch: 0355 loss_train: 2.6108 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0356 loss_train: 2.6119 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0357 loss_train: 2.6099 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0358 loss_train: 2.6101 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0075s
# torch.Size([12009, 28])
# Epoch: 0359 loss_train: 2.6119 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0360 loss_train: 2.6099 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0361 loss_train: 2.6112 acc_train: 0.2710 loss_val: 2.4535 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0362 loss_train: 2.6075 acc_train: 0.2710 loss_val: 2.4534 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0363 loss_train: 2.6104 acc_train: 0.2710 loss_val: 2.4534 acc_val: 0.3955 time: 0.0191s
# torch.Size([12009, 28])
# Epoch: 0364 loss_train: 2.6118 acc_train: 0.2710 loss_val: 2.4534 acc_val: 0.3955 time: 0.0050s
# torch.Size([12009, 28])
# Epoch: 0365 loss_train: 2.6079 acc_train: 0.2710 loss_val: 2.4534 acc_val: 0.3955 time: 0.0128s
# torch.Size([12009, 28])
# Epoch: 0366 loss_train: 2.6114 acc_train: 0.2710 loss_val: 2.4534 acc_val: 0.3955 time: 0.0162s
# torch.Size([12009, 28])
# Epoch: 0367 loss_train: 2.6081 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0196s
# torch.Size([12009, 28])
# Epoch: 0368 loss_train: 2.6076 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0101s
# torch.Size([12009, 28])
# Epoch: 0369 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0370 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0039s
# torch.Size([12009, 28])
# Epoch: 0371 loss_train: 2.6113 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0372 loss_train: 2.6110 acc_train: 0.2710 loss_val: 2.4533 acc_val: 0.3955 time: 0.0188s
# torch.Size([12009, 28])
# Epoch: 0373 loss_train: 2.6061 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0374 loss_train: 2.6100 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0138s
# torch.Size([12009, 28])
# Epoch: 0375 loss_train: 2.6080 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0178s
# torch.Size([12009, 28])
# Epoch: 0376 loss_train: 2.6090 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0010s
# torch.Size([12009, 28])
# Epoch: 0377 loss_train: 2.6084 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0169s
# torch.Size([12009, 28])
# Epoch: 0378 loss_train: 2.6103 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0379 loss_train: 2.6061 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0117s
# torch.Size([12009, 28])
# Epoch: 0380 loss_train: 2.6084 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0145s
# torch.Size([12009, 28])
# Epoch: 0381 loss_train: 2.6056 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0382 loss_train: 2.6094 acc_train: 0.2710 loss_val: 2.4532 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0383 loss_train: 2.6091 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0108s
# torch.Size([12009, 28])
# Epoch: 0384 loss_train: 2.6079 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0385 loss_train: 2.6081 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0386 loss_train: 2.6081 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0387 loss_train: 2.6104 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0388 loss_train: 2.6137 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0389 loss_train: 2.6129 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0390 loss_train: 2.6074 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0391 loss_train: 2.6060 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0392 loss_train: 2.6046 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0393 loss_train: 2.6111 acc_train: 0.2710 loss_val: 2.4531 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0394 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0119s
# torch.Size([12009, 28])
# Epoch: 0395 loss_train: 2.6101 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0396 loss_train: 2.6071 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0397 loss_train: 2.6085 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0143s
# torch.Size([12009, 28])
# Epoch: 0398 loss_train: 2.6095 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0399 loss_train: 2.6112 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0134s
# torch.Size([12009, 28])
# Epoch: 0400 loss_train: 2.6067 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0166s
# torch.Size([12009, 28])
# Epoch: 0401 loss_train: 2.6083 acc_train: 0.2710 loss_val: 2.4530 acc_val: 0.3955 time: 0.0136s
# torch.Size([12009, 28])
# Epoch: 0402 loss_train: 2.6072 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0069s
# torch.Size([12009, 28])
# Epoch: 0403 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0170s
# torch.Size([12009, 28])
# Epoch: 0404 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0171s
# torch.Size([12009, 28])
# Epoch: 0405 loss_train: 2.6097 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0150s
# torch.Size([12009, 28])
# Epoch: 0406 loss_train: 2.6061 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0165s
# torch.Size([12009, 28])
# Epoch: 0407 loss_train: 2.6055 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0127s
# torch.Size([12009, 28])
# Epoch: 0408 loss_train: 2.6116 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0409 loss_train: 2.6104 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0135s
# torch.Size([12009, 28])
# Epoch: 0410 loss_train: 2.6056 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0163s
# torch.Size([12009, 28])
# Epoch: 0411 loss_train: 2.6083 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0183s
# torch.Size([12009, 28])
# Epoch: 0412 loss_train: 2.6064 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0413 loss_train: 2.6068 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0414 loss_train: 2.6080 acc_train: 0.2710 loss_val: 2.4529 acc_val: 0.3955 time: 0.0093s
# torch.Size([12009, 28])
# Epoch: 0415 loss_train: 2.6063 acc_train: 0.2710 loss_val: 2.4528 acc_val: 0.3955 time: 0.0118s
# torch.Size([12009, 28])
# Epoch: 0416 loss_train: 2.6043 acc_train: 0.2710 loss_val: 2.4528 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0417 loss_train: 2.6095 acc_train: 0.2710 loss_val: 2.4528 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0418 loss_train: 2.6055 acc_train: 0.2710 loss_val: 2.4528 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0419 loss_train: 2.6087 acc_train: 0.2710 loss_val: 2.4528 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0420 loss_train: 2.6054 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0157s
# torch.Size([12009, 28])
# Epoch: 0421 loss_train: 2.6034 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0422 loss_train: 2.6088 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0423 loss_train: 2.6106 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0246s
# torch.Size([12009, 28])
# Epoch: 0424 loss_train: 2.6016 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0425 loss_train: 2.6107 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0426 loss_train: 2.6089 acc_train: 0.2710 loss_val: 2.4527 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0427 loss_train: 2.6074 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0428 loss_train: 2.6041 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0429 loss_train: 2.6078 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0430 loss_train: 2.6096 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0431 loss_train: 2.6050 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0186s
# torch.Size([12009, 28])
# Epoch: 0432 loss_train: 2.6070 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0138s
# torch.Size([12009, 28])
# Epoch: 0433 loss_train: 2.6067 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0434 loss_train: 2.6074 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0435 loss_train: 2.6058 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0028s
# torch.Size([12009, 28])
# Epoch: 0436 loss_train: 2.6062 acc_train: 0.2710 loss_val: 2.4526 acc_val: 0.3955 time: 0.0130s
# torch.Size([12009, 28])
# Epoch: 0437 loss_train: 2.6038 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0157s
# torch.Size([12009, 28])
# Epoch: 0438 loss_train: 2.6047 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0155s
# torch.Size([12009, 28])
# Epoch: 0439 loss_train: 2.6031 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0440 loss_train: 2.6058 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0441 loss_train: 2.6014 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0442 loss_train: 2.6077 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0443 loss_train: 2.6096 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0444 loss_train: 2.6068 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0445 loss_train: 2.6031 acc_train: 0.2710 loss_val: 2.4525 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0446 loss_train: 2.6052 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0447 loss_train: 2.6051 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0448 loss_train: 2.6077 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0184s
# torch.Size([12009, 28])
# Epoch: 0449 loss_train: 2.6071 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0073s
# torch.Size([12009, 28])
# Epoch: 0450 loss_train: 2.6034 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0187s
# torch.Size([12009, 28])
# Epoch: 0451 loss_train: 2.6062 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0452 loss_train: 2.6097 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0453 loss_train: 2.6009 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0454 loss_train: 2.6039 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0455 loss_train: 2.6053 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0456 loss_train: 2.6042 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0457 loss_train: 2.6102 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0458 loss_train: 2.6058 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0459 loss_train: 2.6022 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0460 loss_train: 2.6031 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0461 loss_train: 2.6071 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0462 loss_train: 2.6022 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0246s
# torch.Size([12009, 28])
# Epoch: 0463 loss_train: 2.6089 acc_train: 0.2710 loss_val: 2.4524 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0464 loss_train: 2.6026 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0150s
# torch.Size([12009, 28])
# Epoch: 0465 loss_train: 2.6055 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0273s
# torch.Size([12009, 28])
# Epoch: 0466 loss_train: 2.6032 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0154s
# torch.Size([12009, 28])
# Epoch: 0467 loss_train: 2.6032 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0130s
# torch.Size([12009, 28])
# Epoch: 0468 loss_train: 2.6039 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0469 loss_train: 2.5993 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0161s
# torch.Size([12009, 28])
# Epoch: 0470 loss_train: 2.6040 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0471 loss_train: 2.6053 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0249s
# torch.Size([12009, 28])
# Epoch: 0472 loss_train: 2.6047 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0150s
# torch.Size([12009, 28])
# Epoch: 0473 loss_train: 2.6110 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0474 loss_train: 2.6099 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0475 loss_train: 2.6049 acc_train: 0.2710 loss_val: 2.4523 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0476 loss_train: 2.6003 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0477 loss_train: 2.6055 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0478 loss_train: 2.6020 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0479 loss_train: 2.6039 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0480 loss_train: 2.6030 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0481 loss_train: 2.6013 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0084s
# torch.Size([12009, 28])
# Epoch: 0482 loss_train: 2.6007 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0182s
# torch.Size([12009, 28])
# Epoch: 0483 loss_train: 2.6085 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0109s
# torch.Size([12009, 28])
# Epoch: 0484 loss_train: 2.6014 acc_train: 0.2710 loss_val: 2.4522 acc_val: 0.3955 time: 0.0158s
# torch.Size([12009, 28])
# Epoch: 0485 loss_train: 2.6004 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0080s
# torch.Size([12009, 28])
# Epoch: 0486 loss_train: 2.6070 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0487 loss_train: 2.6080 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0081s
# torch.Size([12009, 28])
# Epoch: 0488 loss_train: 2.6049 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0000s
# torch.Size([12009, 28])
# Epoch: 0489 loss_train: 2.5984 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0156s
# torch.Size([12009, 28])
# Epoch: 0490 loss_train: 2.6052 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0159s
# torch.Size([12009, 28])
# Epoch: 0491 loss_train: 2.6017 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0085s
# torch.Size([12009, 28])
# Epoch: 0492 loss_train: 2.6043 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0183s
# torch.Size([12009, 28])
# Epoch: 0493 loss_train: 2.6024 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0160s
# torch.Size([12009, 28])
# Epoch: 0494 loss_train: 2.6026 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0051s
# torch.Size([12009, 28])
# Epoch: 0495 loss_train: 2.6014 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0170s
# torch.Size([12009, 28])
# Epoch: 0496 loss_train: 2.6014 acc_train: 0.2710 loss_val: 2.4520 acc_val: 0.3955 time: 0.0168s
# torch.Size([12009, 28])
# Epoch: 0497 loss_train: 2.6073 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0132s
# torch.Size([12009, 28])
# Epoch: 0498 loss_train: 2.6059 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0167s
# torch.Size([12009, 28])
# Epoch: 0499 loss_train: 2.6057 acc_train: 0.2710 loss_val: 2.4520 acc_val: 0.3955 time: 0.0212s
# torch.Size([12009, 28])
# Epoch: 0500 loss_train: 2.6028 acc_train: 0.2710 loss_val: 2.4521 acc_val: 0.3955 time: 0.0154s
# Optimization Finished!
# Total time elapsed: 6.5079s

# %% [markdown]
# ### Testing

# %%
test(model)
